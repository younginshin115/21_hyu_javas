# %% [markdown]
# # 데이터 로드

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 7.2 MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 55.4 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
# 필요 프레임워크 및 라이브러리 준비
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import re
import urllib.request
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# 사전에 정제+정규화된 훈련용 통합 데이터 로드
total_data = pd.read_table('clean_naver_shopping_review_total_data.txt')

# %%
# 통합 데이터 확인
print(len(total_data))
# Out:
# 199908

# %%
print(total_data[:3])
# Out:
#    ratings                                           document  label
# 0        2                              입고다니기 좀그래요 실내에서만 입으세요      0
# 1        4  포장박스가 살짝오픈되어 있어서 조금 그랬는데 상품은 이상없었고 예상했던맛이며 공복에...      1
# 2        2         직원분 실수로 잘못 배달되어져서 간장소스거 와버렸죠그래도 와사비는 맛좋으네요      0

# %% [markdown]
# # 토큰화

# %%
# 불용어 정의 (한국어 조사, 접속사 등) 
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
# 훈련데이터에 형태소 분석기를 사용하여 토큰화를 하면서 불용어 제거
okt = Okt()
X_total = []
for sentence in total_data['document']:
    temp_X = okt.morphs(sentence, stem=True) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    X_total.append(temp_X)

# %%
print(len(X_total))
print(X_total[:3])
# Out:
# 199908
# [['입다', '그렇다', '실내', '에서만', '입다'], ['포장', '박스', '살짝', '오픈', '되어다', '있다', '조금', '그랬는데', '상품', '이상', '없다', '예상', '맛', '이며', '공복', '꼭꼭', '씹다', '먹다', '혈당', '빠르다', '올라가다', '않다', '만족스럽다'], ['직원', '분', '실수', '로', '잘못', '배달', '되어다', '간장', '소스', '거', '오다', '버리다', '그래도', '와사비', '맛', '좋다']]

# %% [markdown]
# # 정수 인코딩

# %%
# 기계가 텍스트를 숫자로 처리할 수 있도록 데이터를 정수로 변환
# 일단 단어 집합을 만들자
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_total)
 # fit_on_texts()안에 코퍼스를 입력으로 하면 빈도수를 기준으로 단어 집합을 생성한다.
 # 단어 빈도수가 높은순으로 낮은 정수 인덱스 부여

# %%
print(len(tokenizer.word_index))
print(tokenizer.word_index)
print(tokenizer.word_counts)
# Out:
# 42467
# {'좋다': 1, '너무': 2, '배송': 3, '요': 4, '보다': 5, '같다': 6, '있다': 7, '자다': 8, '안': 9, '먹다': 10, '재다': 11, '않다': 12, '구매': 13, '없다': 14, '이다': 15, '다': 16, '쓰다': 17, '오다': 18, '사용': 19, '되다': 20, '로': 21, '사다': 22, '을': 23, '그냥': 24, '제품': 25, '빠르다': 26, '가격': 27, '생각': 28, '받다': 29, '주문': 30, '맛': 31, '고': 32, '많이': 33, '하고': 34, '아니다': 35, '더': 36, '못': 37, '별로': 38, '때': 39, '만': 40, '것': 41, '사이즈': 42, 'ㅠㅠ': 43, '들다': 44, '만족하다': 45, '맛있다': 46, '에서': 47, '개': 48, '포장': 49, '써다': 50, '크다': 51, '네': 52, '편하다': 53, '그렇다': 54, '작다': 55, '맞다': 56, '서': 57, '거': 58, '상품': 59, '안되다': 60, '괜찮다': 61, '저렴하다': 62, '이쁘다': 63, 'ㅠ': 64, '넘다': 65, '싸다': 66, '정말': 67, '다른': 68, '냄새': 69, '부분': 70, '보내다': 71, '시키다': 72, '제': 73, '나다': 74, '나': 75, '인데': 76, '예쁘다': 77, '모르다': 78, '버리다': 79, 'ㅎㅎ': 80, '하나': 81, '이라': 82, '아주': 83, '두': 84, '진짜': 85, '감사하다': 86, '저': 87, '많다': 88, '되어다': 89, '구입': 90, '조금': 91, '또': 92, '좋아하다': 93, '반품': 94, '입다': 95, '아쉽다': 96, 'ㅜㅜ': 97, '쓸다': 98, '가다': 99, '딱': 100, '아이': 101, '정도': 102, '아직': 103, '느낌': 104, '맘': 105, '깔끔하다': 106, '중': 107, '완전': 108, '엄청': 109, '불편하다': 110, '떨어지다': 111, '알다': 112, '게': 113, '나오다': 114, '용': 115, '처음': 116, '넣다': 117, '해주다': 118, '면': 119, '주다': 120, '일': 121, '디자인': 122, '사진': 123, '비': 124, '효과': 125, '그': 126, '라': 127, '다시': 128, '튼튼하다': 129, '상태': 130, '구': 131, '선물': 132, '지': 133, '한번': 134, '인': 135, '대비': 136, '추천': 137, '에요': 138, '보고': 139, '얇다': 140, '전': 141, '크기': 142, '향': 143, '색상': 144, '하': 145, '걸': 146, '잘쓰다': 147, '적': 148, '이네': 149, '귀찮다': 150, 'ㅎ': 151, '걸리다': 152, '빠지다': 153, '해보다': 154, '교환': 155, '해': 156, '랑': 157, '수': 158, '여': 159, '계속': 160, '까지': 161, '비싸다': 162, '어': 163, '없이': 164, '분': 165, 'ㅋㅋ': 166, '에는': 167, '마음': 168, '물건': 169, '엔': 170, '예요': 171, '아': 172, '느리다': 173, '다르다': 174, '싶다': 175, 'ㅜ': 176, '이에요': 177, '말다': 178, '가성': 179, '보이다': 180, '다음': 181, '바로': 182, '늘다': 183, '집': 184, '약하다': 185, '항상': 186, '번': 187, '박스': 188, '돼다': 189, 'ㅡㅡ': 190, '듯': 191, '설치': 192, '실망': 193, '돈': 194, '만족': 195, '이랑': 196, '아기': 197, '색': 198, '조립': 199, '빨르다': 200, '곳': 201, '같이': 202, '택배': 203, '후': 204, '들어가다': 205, '주': 206, '대': 207, '불량': 208, '이번': 209, '드리다': 210, '옷': 211, '붙다': 212, '건지다': 213, '늦다': 214, '오래': 215, '부드럽다': 216, '그리고': 217, '달': 218, '니': 219, '에도': 220, '물': 221, '그래도': 222, '여기': 223, '기': 224, '가볍다': 225, '근데': 226, '시간': 227, '마감': 228, '믿다': 229, '이나': 230, '붙이다': 231, '두다': 232, '사': 233, '잇다': 234, '파다': 235, '내': 236, '심하다': 237, '확인': 238, '왜': 239, '역시': 240, '재질': 241, '최고': 242, '력': 243, '시': 244, '일단': 245, '뭐': 246, '기다': 247, '감': 248, '별': 249, '짜다': 250, '적당하다': 251, 'ㅋ': 252, '처럼': 253, '매': 254, '살다': 255, '지다': 256, '쓰기': 257, '힘들다': 258, '기분': 259, '빼다': 260, '시원하다': 261, '손': 262, '후기': 263, '만들다': 264, '매우': 265, '안좋다': 266, '터지다': 267, '굿': 268, '줄': 269, '아깝다': 270, '때문': 271, '약간': 272, '날': 273, '문': 274, '쉬다': 275, '판매': 276, '품질': 277, '이건': 278, '뜯다': 279, '착용': 280, '빨리': 281, '인지': 282, '차다': 283, '라서': 284, '알': 285, '이렇게': 286, '오': 287, '짧다': 288, '하루': 289, '앞': 290, '늘': 291, '아프다': 292, '길이': 293, '끄다': 294, '고정': 295, '먹기': 296, '비추다': 297, '피부': 298, '문제': 299, '소리': 300, '너': 301, '꼼꼼하다': 302, '원': 303, '이렇다': 304, '필요하다': 305, '지만': 306, '만족스럽다': 307, '살짝': 308, '양': 309, '최악': 310, '씩': 311, '리뷰': 312, '덥다': 313, '원래': 314, '말': 315, '머리': 316, '전혀': 317, '점': 318, '비다': 319, '햇': 320, '여름': 321, '나서다': 322, '귀엽다': 323, '처리': 324, '뚜껑': 325, '세': 326, '두껍다': 327, '놓다': 328, '적다': 329, '이고': 330, '묻다': 331, '바르다': 332, '장': 333, 'ㅋㅋㅋ': 334, '건': 335, '추가': 336, '제대로': 337, '신경': 338, '마다': 339, '자꾸': 340, '만에': 341, '여러': 342, '하지만': 343, '감다': 344, '사서': 345, '생기다': 346, '임': 347, '걱정': 348, '이상': 349, '자주': 350, '케이스': 351, '연락': 352, '먼지': 353, '허다': 354, '애': 355, '어떻다': 356, '잘못': 357, '도착': 358, '사람': 359, '성': 360, '금방': 361, '세탁': 362, '설명': 363, '데': 364, '달라': 365, '재': 366, '야하다': 367, '색깔': 368, '몇': 369, '서다': 370, '끈': 371, '반': 372, '기대': 373, '충전': 374, '부터': ...
# OrderedDict([('입다', 4176), ('그렇다', 6520), ('실내', 171), ('에서만', 131), ('포장', 7128), ('박스', 2385), ('살짝', 1346), ('오픈', 106), ('되어다', 4371), ('있다', 22327), ('조금', 4333), ('그랬는데', 57), ('상품', 6054), ('이상', 1194), ('없다', 15495), ('예상', 212), ('맛', 9569), ('이며', 186), ('공복', 16), ('꼭꼭', 14), ('씹다', 263), ('먹다', 17823), ('혈당', 15), ('빠르다', 11826), ('올라가다', 388), ('않다', 16172), ('만족스럽다', 1348), ('직원', 180), ('분', 2599), ('실수', 299), ('로', 13481), ('잘못', 1176), ('배달', 463), ('간장', 158), ('소스', 296), ('거', 6225), ('오다', 13672), ('버리다', 4778), ('그래도', 2007), ('와사비', 45), ('좋다', 60991), ('색', 2207), ('괜찮다', 5974), ('얇다', 2986), ('금방', 1169), ('구멍', 1104), ('나', 4854), ('요', 24538), ('재다', 16686), ('가격', 11596), ('시중', 150), ('살다', 1736), ('비싸다', 2617), ('부담스럽다', 109), ('별로', 8004), ('에요', 3018), ('배송', 28486), ('너무', 29754), ('늦다', 2080), ('느리다', 2546), ('사용설명서', 48), ('하', 2902), ('기다리다', 997), ('보람', 94), ('목', 691), ('빠지다', 2807), ('알다', 3579), ('고별', 8), ('제', 5043), ('구', 3126), ('매', 1741), ('의사', 973), ('전혀', 1309), ('효과', 3201), ('ㅠㅠ', 7627), ('식탁', 199), ('에서', 7143), ('삼겹살', 50), ('막', 956), ('굽다', 435), ('같다', 22438), ('아주', 4721), ('자다', 20237), ('도착', 1176), ('저희', 720), ('아이', 4010), ('호환', 162), ('안되다', 6029), ('더', 8501), ('확인', 1849), ('해보다', 2789), ('겠다', 474), ('우선', 422), ('사용', 13663), ('하고', 8774), ('핀', 227), ('충전기', 200), ('하고는', 94), ('항상', 2398), ('잘쓰다', 2869), ('감사하다', 4626), ('많이', 8904), ('파다', 1898), ('벨', 103), ('크다', 6717), ('부분', 5396), ('뜯다', 1563), ('저렴하다', 5959), ('그램스', 1), ('정말', 5577), ('많다', 4536), ('게임', 188), ('즐겁다', 121), ('엄마', 919), ('방', 356), ('쓰다', 14092), ('구매', 15632), ('회전력', 3), ('약하다', 2401), ('때', 7927), ('벗겨지다', 698), ('만', 7851), ('힘', 825), ('을', 13196), ('가하다', 86), ('정지', 8), ('되다', 13619), ('파워', 28), ('별', 1772), ('쓸모', 86), ('오래', 2070), ('걸리다', 2810), ('취소', 430), ('중', 3799), ('이라', 4741), ('뜨다', 970), ('어쩔', 526), ('수없이', 117), ('받다', 10063), ('바지', 808), ('그냥', 12469), ('저', 4578), ('냥', 663), ('집', 2406), ('덥다', 1323), ('아', 2561), ('믿다', 1955), ('산', 744), ('링', 259), ('사이즈', 7644), ('하나', 4742), ('안', 19444), ('맞다', 6287), ('속상하다', 392), ('돈', 2316), ('얼마', 402), ('인지', 1541), ('플라스틱', 736), ('그', 3183), ('런가', 320), ('애매하다', 289), ('뇨', 63), ('짜다', 1766), ('ㅡㅡ', 2345), ('롭', 7), ('밉다', 397), ('맛없다', 636), ('다', 14707), ('비려', 91), ('전', 2964), ('못', 8264), ('예민하다', 206), ('왜', 1847), ('빔', 27), ('나오다', 3462), ('ㅠ', 5860), ('건전지', 223), ('함께', 394), ('살걸', 275), ('랫', 77), ('네', 6708), ('치마', 119), ('같이', 2194), ('넓다', 551), ('예쁘다', 4810), ('재', 1163), ('뿜뿜', 17), ('집들이', 98), ('선물', 3125), ('려고', 410), ('사다', 13448), ('좋아하다', 4214), ('두껍다', 1279), ('기다', 1797), ('하지만', 1210), ('물', 2011), ('흡수', 500), ('력', 1825), ('여전하다', 205), ('오늘', 779), ('끈', 1137), ('적', 2849), ('이지', 343), ('ㄱ', 277), ('느', 57), ('것', 7707), ('빨', 1115), ('라서', 1529), ('ㅈ', 285), ('ㅗㅎ', 17), ('았', 92), ('어', 2614), ('역시', 1846), ('기대', 1129), ('대로', 624), ('이다', 15216), ('끌다', 120), ('몸', 478), ('안좋다', 1641), ('글루타민산', 1), ('나트륨', 6), ('넣다', 3351), ('찝찝하다', 359), ('향', 2953), ('문제', 1407), ('아니다', 8514), ('손목', 194), ('분사', 193), ('후', 2176), ('몇', 1149), ('분안', 12), ('빨갛다', 201), ('부어', 59), ('올라서다', 25), ('살', 1061), ('엔', 2567), ('뿌리다', 482), ('방향', 149), ('또는', 44), ('옷', 2102), ('이에요', 2515), ('바퀴', 356), ('굴러가다', 59), ('만족', 2304), ('물건', 2575), ('편하다', 6559), ('재미나', 12), ('게', 3572), ('모두', 963), ('만족하다', 7315), ('다만', 960), ('휘', 507), ('지다', 1733), ('가운데', 251), ('서랍', 469), ('장', 1263), ('들이다', 248), ('들어가다', 2162), ('붕', 66), ('현상', 218), ('딱', 4019), ('곧다', 13), ('펴다', 666), ('조립', 2207), ('바라다', 568), ('짧다', 1468), ('선', 512), ('보조', 133), ('베터리', 51), ('연결하다', 319), ('도거', 9), ('주가', 43), ('아직', 3911), ('가보다', 333), ('일단', 1809), ('넘다', 5785), ('조카', 232), ('인', 3047), ('어울리다', 530), ('매우', 1649), ('예요', 2566), ('앉다', 466), ('엉덩이', 321), ('곡선', 25), ('애기', 788), ('밥', 510), ('줄', 1617), ('옆', 572), ('불편하다', 3683), ('디자인', 3285), ('가성', 2488), ('비', 3262), ('대', 2158), ('녹다', 998), ...

# %%
# 등장 빈도수가 낮은 데이터를 처리해보자
# 특정 횟수 이하 단어의 비중이 몇인지 체크
threshold = 25
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 42467
# 등장 빈도가 24번 이하인 희귀 단어의 수: 37138
# 단어 집합에서 희귀 단어의 비율: 87.45143287729296
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 4.975221975835322

# %%
# 전체 단어 개수 중 빈도수 12이하인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 5330

# %%
# 단어집합을 케라스 토크나이저의 인자로 넘겨주면, 케라스 토크나이저는 텍스트 시퀀스를 숫자 시퀀스로 변환
#Tokenizer메서드에 숫자를 입력하면 빈도수가 높은 상위 몇개 단어만 사용
tokenizer = Tokenizer(num_words = vocab_size +2, oov_token ='OOV')
# 빈도수 상위 vocab_size단어만 사용, 숫자 0과 OOV를 고려해서 단어 집합의 크기는 +2
tokenizer.fit_on_texts(X_total)
# 여기까지는 보캡길이가 적용안된 것처럼 보임, 실제 적용은 text_to_sequences사용시 적용됨
X_total = tokenizer.texts_to_sequences(X_total)

# vocab_size로 지정한 단어만 보존하고 싶을 때, 굳이 안해도됨
# words_frequency = [w for w,c in tokenizer.word_index.items() if c >= vocab_size + 1] # 인덱스가 5 초과인 단어 제거
# for w in words_frequency:
#     del tokenizer.word_index[w] # 해당 단어에 대한 인덱스 정보를 삭제
#     del tokenizer.word_counts[w] # 해당 단어에 대한 카운트 정보를 삭제

# 정수인코딩 결과 확인
print(len(tokenizer.word_index))
print(tokenizer.word_index)
print(tokenizer.word_counts)

# 빈도수 상위 vocabsize개수의 단어는 2 ~ vocabsize+1까지의 인덱스를 가졌으며, 그 외 단어 집합에 없는 단어들은 전부 'OOV'의 인덱스인 1로 인코딩
# 케라스 토크나이저는 기본적으로 'OOV'의 인덱스를 1로 지정
# print('단어 OOV의 인덱스 : {}'.format(tokenizer.word_index['OOV']))
# Out:
# 42468
# {'OOV': 1, '좋다': 2, '너무': 3, '배송': 4, '요': 5, '보다': 6, '같다': 7, '있다': 8, '자다': 9, '안': 10, '먹다': 11, '재다': 12, '않다': 13, '구매': 14, '없다': 15, '이다': 16, '다': 17, '쓰다': 18, '오다': 19, '사용': 20, '되다': 21, '로': 22, '사다': 23, '을': 24, '그냥': 25, '제품': 26, '빠르다': 27, '가격': 28, '생각': 29, '받다': 30, '주문': 31, '맛': 32, '고': 33, '많이': 34, '하고': 35, '아니다': 36, '더': 37, '못': 38, '별로': 39, '때': 40, '만': 41, '것': 42, '사이즈': 43, 'ㅠㅠ': 44, '들다': 45, '만족하다': 46, '맛있다': 47, '에서': 48, '개': 49, '포장': 50, '써다': 51, '크다': 52, '네': 53, '편하다': 54, '그렇다': 55, '작다': 56, '맞다': 57, '서': 58, '거': 59, '상품': 60, '안되다': 61, '괜찮다': 62, '저렴하다': 63, '이쁘다': 64, 'ㅠ': 65, '넘다': 66, '싸다': 67, '정말': 68, '다른': 69, '냄새': 70, '부분': 71, '보내다': 72, '시키다': 73, '제': 74, '나다': 75, '나': 76, '인데': 77, '예쁘다': 78, '모르다': 79, '버리다': 80, 'ㅎㅎ': 81, '하나': 82, '이라': 83, '아주': 84, '두': 85, '진짜': 86, '감사하다': 87, '저': 88, '많다': 89, '되어다': 90, '구입': 91, '조금': 92, '또': 93, '좋아하다': 94, '반품': 95, '입다': 96, '아쉽다': 97, 'ㅜㅜ': 98, '쓸다': 99, '가다': 100, '딱': 101, '아이': 102, '정도': 103, '아직': 104, '느낌': 105, '맘': 106, '깔끔하다': 107, '중': 108, '완전': 109, '엄청': 110, '불편하다': 111, '떨어지다': 112, '알다': 113, '게': 114, '나오다': 115, '용': 116, '처음': 117, '넣다': 118, '해주다': 119, '면': 120, '주다': 121, '일': 122, '디자인': 123, '사진': 124, '비': 125, '효과': 126, '그': 127, '라': 128, '다시': 129, '튼튼하다': 130, '상태': 131, '구': 132, '선물': 133, '지': 134, '한번': 135, '인': 136, '대비': 137, '추천': 138, '에요': 139, '보고': 140, '얇다': 141, '전': 142, '크기': 143, '향': 144, '색상': 145, '하': 146, '걸': 147, '잘쓰다': 148, '적': 149, '이네': 150, '귀찮다': 151, 'ㅎ': 152, '걸리다': 153, '빠지다': 154, '해보다': 155, '교환': 156, '해': 157, '랑': 158, '수': 159, '여': 160, '계속': 161, '까지': 162, '비싸다': 163, '어': 164, '없이': 165, '분': 166, 'ㅋㅋ': 167, '에는': 168, '마음': 169, '물건': 170, '엔': 171, '예요': 172, '아': 173, '느리다': 174, '다르다': 175, '싶다': 176, 'ㅜ': 177, '이에요': 178, '말다': 179, '가성': 180, '보이다': 181, '다음': 182, '바로': 183, '늘다': 184, '집': 185, '약하다': 186, '항상': 187, '번': 188, '박스': 189, '돼다': 190, 'ㅡㅡ': 191, '듯': 192, '설치': 193, '실망': 194, '돈': 195, '만족': 196, '이랑': 197, '아기': 198, '색': 199, '조립': 200, '빨르다': 201, '곳': 202, '같이': 203, '택배': 204, '후': 205, '들어가다': 206, '주': 207, '대': 208, '불량': 209, '이번': 210, '드리다': 211, '옷': 212, '붙다': 213, '건지다': 214, '늦다': 215, '오래': 216, '부드럽다': 217, '그리고': 218, '달': 219, '니': 220, '에도': 221, '물': 222, '그래도': 223, '여기': 224, '기': 225, '가볍다': 226, '근데': 227, '시간': 228, '마감': 229, '믿다': 230, '이나': 231, '붙이다': 232, '두다': 233, '사': 234, '잇다': 235, '파다': 236, '내': 237, '심하다': 238, '확인': 239, '왜': 240, '역시': 241, '재질': 242, '최고': 243, '력': 244, '시': 245, '일단': 246, '뭐': 247, '기다': 248, '감': 249, '별': 250, '짜다': 251, '적당하다': 252, 'ㅋ': 253, '처럼': 254, '매': 255, '살다': 256, '지다': 257, '쓰기': 258, '힘들다': 259, '기분': 260, '빼다': 261, '시원하다': 262, '손': 263, '후기': 264, '만들다': 265, '매우': 266, '안좋다': 267, '터지다': 268, '굿': 269, '줄': 270, '아깝다': 271, '때문': 272, '약간': 273, '날': 274, '문': 275, '쉬다': 276, '판매': 277, '품질': 278, '이건': 279, '뜯다': 280, '착용': 281, '빨리': 282, '인지': 283, '차다': 284, '라서': 285, '알': 286, '이렇게': 287, '오': 288, '짧다': 289, '하루': 290, '앞': 291, '늘': 292, '아프다': 293, '길이': 294, '끄다': 295, '고정': 296, '먹기': 297, '비추다': 298, '피부': 299, '문제': 300, '소리': 301, '너': 302, '꼼꼼하다': 303, '원': 304, '이렇다': 305, '필요하다': 306, '지만': 307, '만족스럽다': 308, '살짝': 309, '양': 310, '최악': 311, '씩': 312, '리뷰': 313, '덥다': 314, '원래': 315, '말': 316, '머리': 317, '전혀': 318, '점': 319, '비다': 320, '햇': 321, '여름': 322, '나서다': 323, '귀엽다': 324, '처리': 325, '뚜껑': 326, '세': 327, '두껍다': 328, '놓다': 329, '적다': 330, '이고': 331, '묻다': 332, '바르다': 333, '장': 334, 'ㅋㅋㅋ': 335, '건': 336, '추가': 337, '제대로': 338, '신경': 339, '마다': 340, '자꾸': 341, '만에': 342, '여러': 343, '하지만': 344, '감다': 345, '사서': 346, '생기다': 347, '임': 348, '걱정': 349, '이상': 350, '자주': 351, '케이스': 352, '연락': 353, '먼지': 354, '허다': 355, '애': 356, '어떻다': 357, '잘못': 358, '도착': 359, '사람': 360, '성': 361, '금방': 362, '세탁': 363, '설명': 364, '데': 365, '달라': 366, '재': 367, '야하다': 368, '색깔': 369, '몇': 370, '서다': 371, '끈': 372, '반': 373, '기대': 374, '충전' ...
# OrderedDict([('입다', 4176), ('그렇다', 6520), ('실내', 171), ('에서만', 131), ('포장', 7128), ('박스', 2385), ('살짝', 1346), ('오픈', 106), ('되어다', 4371), ('있다', 22327), ('조금', 4333), ('그랬는데', 57), ('상품', 6054), ('이상', 1194), ('없다', 15495), ('예상', 212), ('맛', 9569), ('이며', 186), ('공복', 16), ('꼭꼭', 14), ('씹다', 263), ('먹다', 17823), ('혈당', 15), ('빠르다', 11826), ('올라가다', 388), ('않다', 16172), ('만족스럽다', 1348), ('직원', 180), ('분', 2599), ('실수', 299), ('로', 13481), ('잘못', 1176), ('배달', 463), ('간장', 158), ('소스', 296), ('거', 6225), ('오다', 13672), ('버리다', 4778), ('그래도', 2007), ('와사비', 45), ('좋다', 60991), ('색', 2207), ('괜찮다', 5974), ('얇다', 2986), ('금방', 1169), ('구멍', 1104), ('나', 4854), ('요', 24538), ('재다', 16686), ('가격', 11596), ('시중', 150), ('살다', 1736), ('비싸다', 2617), ('부담스럽다', 109), ('별로', 8004), ('에요', 3018), ('배송', 28486), ('너무', 29754), ('늦다', 2080), ('느리다', 2546), ('사용설명서', 48), ('하', 2902), ('기다리다', 997), ('보람', 94), ('목', 691), ('빠지다', 2807), ('알다', 3579), ('고별', 8), ('제', 5043), ('구', 3126), ('매', 1741), ('의사', 973), ('전혀', 1309), ('효과', 3201), ('ㅠㅠ', 7627), ('식탁', 199), ('에서', 7143), ('삼겹살', 50), ('막', 956), ('굽다', 435), ('같다', 22438), ('아주', 4721), ('자다', 20237), ('도착', 1176), ('저희', 720), ('아이', 4010), ('호환', 162), ('안되다', 6029), ('더', 8501), ('확인', 1849), ('해보다', 2789), ('겠다', 474), ('우선', 422), ('사용', 13663), ('하고', 8774), ('핀', 227), ('충전기', 200), ('하고는', 94), ('항상', 2398), ('잘쓰다', 2869), ('감사하다', 4626), ('많이', 8904), ('파다', 1898), ('벨', 103), ('크다', 6717), ('부분', 5396), ('뜯다', 1563), ('저렴하다', 5959), ('그램스', 1), ('정말', 5577), ('많다', 4536), ('게임', 188), ('즐겁다', 121), ('엄마', 919), ('방', 356), ('쓰다', 14092), ('구매', 15632), ('회전력', 3), ('약하다', 2401), ('때', 7927), ('벗겨지다', 698), ('만', 7851), ('힘', 825), ('을', 13196), ('가하다', 86), ('정지', 8), ('되다', 13619), ('파워', 28), ('별', 1772), ('쓸모', 86), ('오래', 2070), ('걸리다', 2810), ('취소', 430), ('중', 3799), ('이라', 4741), ('뜨다', 970), ('어쩔', 526), ('수없이', 117), ('받다', 10063), ('바지', 808), ('그냥', 12469), ('저', 4578), ('냥', 663), ('집', 2406), ('덥다', 1323), ('아', 2561), ('믿다', 1955), ('산', 744), ('링', 259), ('사이즈', 7644), ('하나', 4742), ('안', 19444), ('맞다', 6287), ('속상하다', 392), ('돈', 2316), ('얼마', 402), ('인지', 1541), ('플라스틱', 736), ('그', 3183), ('런가', 320), ('애매하다', 289), ('뇨', 63), ('짜다', 1766), ('ㅡㅡ', 2345), ('롭', 7), ('밉다', 397), ('맛없다', 636), ('다', 14707), ('비려', 91), ('전', 2964), ('못', 8264), ('예민하다', 206), ('왜', 1847), ('빔', 27), ('나오다', 3462), ('ㅠ', 5860), ('건전지', 223), ('함께', 394), ('살걸', 275), ('랫', 77), ('네', 6708), ('치마', 119), ('같이', 2194), ('넓다', 551), ('예쁘다', 4810), ('재', 1163), ('뿜뿜', 17), ('집들이', 98), ('선물', 3125), ('려고', 410), ('사다', 13448), ('좋아하다', 4214), ('두껍다', 1279), ('기다', 1797), ('하지만', 1210), ('물', 2011), ('흡수', 500), ('력', 1825), ('여전하다', 205), ('오늘', 779), ('끈', 1137), ('적', 2849), ('이지', 343), ('ㄱ', 277), ('느', 57), ('것', 7707), ('빨', 1115), ('라서', 1529), ('ㅈ', 285), ('ㅗㅎ', 17), ('았', 92), ('어', 2614), ('역시', 1846), ('기대', 1129), ('대로', 624), ('이다', 15216), ('끌다', 120), ('몸', 478), ('안좋다', 1641), ('글루타민산', 1), ('나트륨', 6), ('넣다', 3351), ('찝찝하다', 359), ('향', 2953), ('문제', 1407), ('아니다', 8514), ('손목', 194), ('분사', 193), ('후', 2176), ('몇', 1149), ('분안', 12), ('빨갛다', 201), ('부어', 59), ('올라서다', 25), ('살', 1061), ('엔', 2567), ('뿌리다', 482), ('방향', 149), ('또는', 44), ('옷', 2102), ('이에요', 2515), ('바퀴', 356), ('굴러가다', 59), ('만족', 2304), ('물건', 2575), ('편하다', 6559), ('재미나', 12), ('게', 3572), ('모두', 963), ('만족하다', 7315), ('다만', 960), ('휘', 507), ('지다', 1733), ('가운데', 251), ('서랍', 469), ('장', 1263), ('들이다', 248), ('들어가다', 2162), ('붕', 66), ('현상', 218), ('딱', 4019), ('곧다', 13), ('펴다', 666), ('조립', 2207), ('바라다', 568), ('짧다', 1468), ('선', 512), ('보조', 133), ('베터리', 51), ('연결하다', 319), ('도거', 9), ('주가', 43), ('아직', 3911), ('가보다', 333), ('일단', 1809), ('넘다', 5785), ('조카', 232), ('인', 3047), ('어울리다', 530), ('매우', 1649), ('예요', 2566), ('앉다', 466), ('엉덩이', 321), ('곡선', 25), ('애기', 788), ('밥', 510), ('줄', 1617), ('옆', 572), ('불편하다', 3683), ('디자인', 3285), ('가성', 2488), ('비', 3262), ('대', 2158), ('녹다', 998), ...

# %%
y_total = np.array(total_data['label'])

# %% [markdown]
# # 빈 샘플(empty samples)제거

# %%
# 각 샘플의 길이가 0인 샘플들의 인덱스 확인
drop_total = [index for index, sentence in enumerate(X_total) if len(sentence) < 1]
print(drop_total)
# Out:
# [155188, 170664]

# %%
# 빈 샘플들을 제거
X_total = np.delete(X_total, drop_total, axis=0)
y_total = np.delete(y_total, drop_total, axis=0)
print(len(X_total))
print(len(y_total))
# Out:
# 199906
# 199906
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # 패딩

# %%
# 서로 다른 길이의 샘플들의 길이를 동일하게 맞춰는 작업
# 전체 데이터에서 가장 길이가 긴 리뷰와, 전체의 길이분포를 알아보자
print('리뷰의 최대 길이 :',max(len(l) for l in X_total))
print('리뷰의 평균 길이 :',sum(map(len, X_total))/len(X_total))
plt.hist([len(s) for s in X_total], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 61
# 리뷰의 평균 길이 : 12.086950866907447

# %%
# 최적의 길이를 찾기 위해, 전체 샘플중 길이가 max_len 이하인 샘플의 비율을 확인하는 함수 생성
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
# 비율 체크
max_len = 30
below_threshold_len(max_len, X_total)
# Out:
# 전체 샘플 중 길이가 30 이하인 샘플의 비율: 94.69600712334797

# %%
# 짧은 데이터는 0을 채우고, 35을 넘는 긴 데이터는 손실됨
X_total = pad_sequences(X_total, maxlen = max_len)

# %% [markdown]
# # LSTM/GRU/BiLSTM 모델 훈련

# %%
# 필요한 프레임워크 및 라이브러리 임포트
from tensorflow.keras.layers import Embedding, Dense, GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model_GRU = Sequential()
model_GRU.add(Embedding(vocab_size+2, 100))
model_GRU.add(GRU(128))
model_GRU.add(Dense(1, activation='sigmoid'))

# %%
# 검증 데이터 손실이 4회 증가하면 학습 조기 종료
# model check point를 사용하여 검증 데이터의 정확도가 이전보다 좋아질 경우만 모델 저장
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc_GRU = ModelCheckpoint('RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.1.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
# 필요한 매트릭 선언, AUC-ROC, F1-Score, AUC-PR 에 필요한 지표 모두 체크
import tensorflow as tf

ROCauc = tf.keras.metrics.AUC(curve="ROC") # auc_1
PRauc = tf.keras.metrics.AUC(curve="PR") # auc_2
RECALL = tf.keras.metrics.Recall()
PRECISION = tf.keras.metrics.Precision()
TP = tf.keras.metrics.TruePositives()
TN = tf.keras.metrics.TrueNegatives()
FP = tf.keras.metrics.FalsePositives()
FN = tf.keras.metrics.FalseNegatives()

# %%
# GRU모델 훈련
model_GRU.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc', ROCauc, PRauc, RECALL, PRECISION, TP, TN, FP, FN])
history = model_GRU.fit(X_total, y_total, epochs=15, callbacks=[es, mc_GRU], batch_size=100, validation_split=0.2)
# Out:
# Epoch 1/15
# 1600/1600 [==============================] - 28s 13ms/step - loss: 0.2797 - acc: 0.8915 - auc: 0.9509 - auc_1: 0.9428 - recall: 0.8965 - precision: 0.8877 - true_positives: 71757.0000 - true_negatives: 70811.0000 - false_positives: 9074.0000 - false_negatives: 8282.0000 - val_loss: 0.2499 - val_acc: 0.9060 - val_auc: 0.9608 - val_auc_1: 0.9551 - val_recall: 0.9195 - val_precision: 0.8947 - val_true_positives: 18310.0000 - val_true_negatives: 17914.0000 - val_false_positives: 2156.0000 - val_false_negatives: 1602.0000
#
# Epoch 00001: val_acc improved from -inf to 0.90601, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.1.h5
# Epoch 2/15
# 1600/1600 [==============================] - 19s 12ms/step - loss: 0.2339 - acc: 0.9112 - auc: 0.9649 - auc_1: 0.9594 - recall: 0.9182 - precision: 0.9056 - true_positives: 73491.0000 - true_negatives: 72224.0000 - false_positives: 7661.0000 - false_negatives: 6548.0000 - val_loss: 0.2359 - val_acc: 0.9104 - val_auc: 0.9645 - val_auc_1: 0.9590 - val_recall: 0.9148 - val_precision: 0.9062 - val_true_positives: 18216.0000 - val_true_negatives: 18184.0000 - val_false_positives: 1886.0000 - val_false_negatives: 1696.0000
#
# Epoch 00002: val_acc improved from 0.90601 to 0.91041, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.1.h5
# Epoch 3/15
# 1600/1600 [==============================] - 18s 11ms/step - loss: 0.2194 - acc: 0.9178 - auc: 0.9688 - auc_1: 0.9636 - recall: 0.9260 - precision: 0.9112 - true_positives: 74115.0000 - true_negatives: 72664.0000 - false_positives: 7221.0000 - false_negatives: 5924.0000 - val_loss: 0.2291 - val_acc: 0.9147 - val_auc: 0.9665 - val_auc_1: 0.9609 - val_recall: 0.9176 - val_precision: 0.9117 - val_true_positives: 18272.0000 - val_true_negatives: 18300.0000 - val_false_positives: 1770.0000 - val_false_negatives: 1640.0000
#
# Epoch 00003: val_acc improved from 0.91041 to 0.91471, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.1.h5
# Epoch 4/15
# 1600/1600 [==============================] - 18s 11ms/step - loss: 0.2108 - acc: 0.9215 - auc: 0.9711 - auc_1: 0.9663 - recall: 0.9299 - precision: 0.9147 - true_positives: 74427.0000 - true_negatives: 72945.0000 - false_positives: 6940.0000 - false_negatives: 5612.0000 - val_loss: 0.2274 - val_acc: 0.9153 - val_auc: 0.9670 - val_auc_1: 0.9613 - val_recall: 0.9204 - val_precision: 0.9106 - val_true_positives: 18327.0000 - val_true_negatives: 18270.0000 - val_false_positives: 1800.0000 - val_false_negatives: 1585.0000
#
# Epoch 00004: val_acc improved from 0.91471 to 0.91534, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.1.h5
# Epoch 5/15
# 1600/1600 [==============================] - 20s 12ms/step - loss: 0.2036 - acc: 0.9243 - auc: 0.9729 - auc_1: 0.9686 - recall: 0.9323 - precision: 0.9177 - true_positives: 74622.0000 - true_negatives: 73194.0000 - false_positives: 6691.0000 - false_negatives: 5417.0000 - val_loss: 0.2281 - val_acc: 0.9148 - val_auc: 0.9668 - val_auc_1: 0.9615 - val_recall: 0.9287 - val_precision: 0.9029 - val_true_positives: 18492.0000 - val_true_negatives: 18082.0000 - val_false_positives: 1988.0000 - val_false_negatives: 1420.0000
#
# Epoch 00005: val_acc did not improve from 0.91534
# Epoch 6/15
# 1600/1600 [==============================] - 19s 12ms/step - loss: 0.1970 - acc: 0.9273 - auc: 0.9745 - auc_1: 0.9703 - recall: 0.9347 - precision: 0.9212 - true_positives: 74815.0000 - true_negatives: 73485.0000 - false_positives: 6400.0000 - false_negatives: 5224.0000 - val_loss: 0.2280 - val_acc: 0.9146 - val_auc: 0.9672 - val_auc_1: 0.9619 - val_recall: 0.9320 - val_precision: 0.9000 - val_true_positives: 18558.0000 - val_true_negatives: 18009.0000 - val_false_positives: 2061.0000 - val_false_negatives: 1354.0000
#
# Epoch 00006: val_acc did not improve from 0.91534
# Epoch 7/15
# 1600/1600 [==============================] - 18s 11ms/step - loss: 0.1904 - acc: 0.9305 - auc: 0.9761 - auc_1: 0.9721 - recall: 0.9379 - precision: 0.9244 - true_positives: 75072.0000 - true_negatives: 73745.0000 - false_positives: 6140.0000 - false_negatives: 4967.0000 - val_loss: 0.2297 - val_acc: 0.9160 - val_auc: 0.9669 - val_auc_1: 0.9610 - val_recall: 0.9193 - val_precision: 0.9127 - val_true_positives: 18305.0000 - val_true_negatives: 18319.0000 - val_false_positives: 1751.0000 - val_false_negatives: 1607.0000
#
# Epoch 00007: val_acc improved from 0.91534 to 0.91601, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.1.h5
# Epoch 8/15
# 1600/1600 [==============================] - 19s 12ms/step - loss: 0.1838 - acc: 0.9331 - auc: 0.9776 - auc_1: 0.9742 - recall: 0.9412 - precision: 0.9263 - true_positives: 75333.0000 - true_negatives: 73890.0000 - false_positives: 5995.0000 - false_negatives: 4706.0000 - val_loss: 0.2367 - val_acc: 0.9119 - val_auc: 0.9658 - val_auc_1: 0.9609 - val_recall: 0.8999 - val_precision: 0.9213 - val_true_positives: 17919.0000 - val_true_negatives: 18539.0000 - val_false_positives: 1531.0000 - val_false_negatives: 1993.0000
#
# Epoch 00008: val_acc did not improve from 0.91601
# Epoch 00008: early stopping

# %% [markdown]
# # 모델 성능평가

# %%
# 평가용 토탈 데이터셋2(화장품+앱)

# 데이터 로드
total_data2 = pd.read_table('clean_total_data(app&cosmetic).txt')

# 토크나이징
X_test_total2 = []
for sentence in total_data2['document']:
    temp_X2 = okt.morphs(sentence, stem=True)
    temp_X2 = [word for word in temp_X2 if not word in stopwords]
    X_test_total2.append(temp_X2)

# 워드 벡터화
tokenizer = Tokenizer(vocab_size)
tokenizer.fit_on_texts(X_test_total2)
X_test_total2 = tokenizer.texts_to_sequences(X_test_total2)

# 패딩
X_test_total2 = pad_sequences(X_test_total2, maxlen = max_len)

# 라벨데이터 포함
y_test_total2 = np.array(total_data2['label'])

# %%
# GRU모델 성능 평가 
loaded_model = load_model('RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.1.h5')
result = loaded_model.evaluate(X_test_total2, y_test_total2, batch_size=100)
print("\n GRU 테스트 결과:",result)
# Out:
# 107/107 [==============================] - 2s 6ms/step - loss: 1.2401 - acc: 0.5171 - auc: 0.5377 - auc_1: 0.7169 - recall: 0.5023 - precision: 0.7249 - true_positives: 3745.0000 - true_negatives: 1750.0000 - false_positives: 1421.0000 - false_negatives: 3711.0000
#
#  GRU 테스트 결과: [1.2400604486465454, 0.5170791149139404, 0.5376877188682556, 0.716903567314148, 0.502280056476593, 0.7249322533607483, 3745.0, 1750.0, 1421.0, 3711.0]
