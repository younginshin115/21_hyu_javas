# %% [markdown]
# # 데이터 로드

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 1.4MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 13.0MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/98/88/f817ef1af6f794e8f11313dcd1549de833f4599abcec82746ab5ed086686/JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448kB)
#      |████████████████████████████████| 450kB 40.8MB/s
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Installing collected packages: beautifulsoup4, colorama, JPype1, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
# 필요 프레임워크 및 라이브러리 준비
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import re
import urllib.request
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# 사전에 정제+정규화된 훈련용 통합 데이터 로드
total_data = pd.read_table('total_data(movie&shopping&game).txt')

# %%
# 통합 데이터 확인
print(len(total_data))
# Out:
# 489016
#                                             document  label
# 0                                        이유식 냄비로 좋아요      1
# 1                                       한글화가 없어서짜징난다      0
# 2  에휴 존나 뚝 뚝 끊키는대뭘게임을하라고 무슨 핑은좋은대 게임만들어가면 뚝뚝 끊키고 ...      0

# %%
print(total_data[:3])

# %% [markdown]
# # 토큰화

# %%
# 불용어 정의 (한국어 조사, 접속사 등) 
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
# 훈련데이터에 형태소 분석기를 사용하여 토큰화를 하면서 불용어 제거
okt = Okt()
X_total = []
for sentence in total_data['document']:
    temp_X = okt.morphs(sentence, stem=True) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    X_total.append(temp_X)

# %%
print(len(X_total))
print(X_total[:3])
# Out:
# 489016
# [['이유식', '냄비', '로', '좋다'], ['한글화', '없다', '짜다', '징', '난', '다'], ['휴', '존나', '뚝', '뚝', '끊다', '키', '대', '뭘', '게', '이다', '무슨', '핑', '좋다', '게임', '만', '들어가다', '뚝뚝', '끊다', '키', '고', '걸다', '괜찮다', '또', '총', '쏘다', '뚝뚝', '끊다', '키', '고', '해결', '법', '없다', '뭘', '게', '이다']]

# %%
# 토큰화가 오래걸리므로, 반복작업이 용이하도록 파일로 추출해두자
tokened_vocab = X_total
import json
json = json.dumps(tokened_vocab, ensure_ascii=False)
vacab = open("total_data(movie&shopping&game)_tokened_vocab.json", "w", encoding="utf-8")
vacab.write(json)
vacab.close()

# %% [markdown]
# # 정수 인코딩

# %%
# 기계가 텍스트를 숫자로 처리할 수 있도록 데이터를 정수로 변환
# 일단 단어 집합을 만들자
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_total)
 # fit_on_texts()안에 코퍼스를 입력으로 하면 빈도수를 기준으로 단어 집합을 생성한다.
 # 단어 빈도수가 높은순으로 낮은 정수 인덱스 부여

# %%
# indexed_vocab(vocab) 저장
indexed_vocab = tokenizer.word_index
import json
json = json.dumps(indexed_vocab, ensure_ascii=False)
vacab = open("total_data(movie&shopping&game)_indexed_vocab.json", "w", encoding="utf-8")
vacab.write(json)
vacab.close()

# %%
print(len(tokenizer.word_index))
print(tokenizer.word_index)
print(tokenizer.word_counts)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# 등장 빈도수가 낮은 데이터를 처리해보자
# 특정 횟수 이하 단어의 비중이 몇인지 체크
threshold = 30
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 85794
# 등장 빈도가 29번 이하인 희귀 단어의 수: 75702
# 단어 집합에서 희귀 단어의 비율: 88.2369396461291
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 4.834712834136931

# %%
# 전체 단어 개수 중 빈도수 12이하인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 10093

# %%
# 단어집합을 케라스 토크나이저의 인자로 넘겨주면, 케라스 토크나이저는 텍스트 시퀀스를 숫자 시퀀스로 변환
#Tokenizer메서드에 숫자를 입력하면 빈도수가 높은 상위 몇개 단어만 사용
tokenizer = Tokenizer(num_words = vocab_size +2, oov_token ='OOV')
# 빈도수 상위 vocab_size단어만 사용, 숫자 0과 OOV를 고려해서 단어 집합의 크기는 +2
tokenizer.fit_on_texts(X_total)
# 여기까지는 보캡길이가 적용안된 것처럼 보임, 실제 적용은 text_to_sequences사용시 적용됨
X_total = tokenizer.texts_to_sequences(X_total)

# vocab_size로 지정한 단어만 보존하고 싶을 때, 굳이 안해도됨
# words_frequency = [w for w,c in tokenizer.word_index.items() if c >= vocab_size + 1] # 인덱스가 5 초과인 단어 제거
# for w in words_frequency:
#     del tokenizer.word_index[w] # 해당 단어에 대한 인덱스 정보를 삭제
#     del tokenizer.word_counts[w] # 해당 단어에 대한 카운트 정보를 삭제

# 정수인코딩 결과 확인
print(len(tokenizer.word_index))
print(tokenizer.word_index)
print(tokenizer.word_counts)

# 빈도수 상위 vocabsize개수의 단어는 2 ~ vocabsize+1까지의 인덱스를 가졌으며, 그 외 단어 집합에 없는 단어들은 전부 'OOV'의 인덱스인 1로 인코딩
# 케라스 토크나이저는 기본적으로 'OOV'의 인덱스를 1로 지정
# print('단어 OOV의 인덱스 : {}'.format(tokenizer.word_index['OOV']))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
y_total = np.array(total_data['label'])

# %% [markdown]
# # 빈 샘플(empty samples)제거

# %%
# 각 샘플의 길이가 0인 샘플들의 인덱스 확인
drop_total = [index for index, sentence in enumerate(X_total) if len(sentence) < 1]
print(drop_total)
# Out:
# [14632, 27170, 28289, 31175, 33805, 37436, 39859, 48040, 99571, 113450, 114946, 126973, 141845, 145702, 168731, 179435, 183863, 187775, 188918, 198198, 215387, 217613, 239681, 246668, 254812, 263465, 284469, 329372, 392273, 403856, 418726, 459309]

# %%
# 빈 샘플들을 제거
X_total = np.delete(X_total, drop_total, axis=0)
y_total = np.delete(y_total, drop_total, axis=0)
print(len(X_total))
print(len(y_total))
# Out:
# 488984
# 488984
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # 패딩

# %%
# 서로 다른 길이의 샘플들의 길이를 동일하게 맞춰는 작업
# 전체 데이터에서 가장 길이가 긴 리뷰와, 전체의 길이분포를 알아보자
print('리뷰의 최대 길이 :',max(len(l) for l in X_total))
print('리뷰의 평균 길이 :',sum(map(len, X_total))/len(X_total))
plt.hist([len(s) for s in X_total], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 72
# 리뷰의 평균 길이 : 12.087743157240318

# %%
# 최적의 길이를 찾기 위해, 전체 샘플중 길이가 max_len 이하인 샘플의 비율을 확인하는 함수 생성
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
# 35 이하 비율 체크
max_len = 35
below_threshold_len(max_len, X_total)
# Out:
# 전체 샘플 중 길이가 35 이하인 샘플의 비율: 96.52626670811316

# %%
# 짧은 데이터는 0을 채우고, 35을 넘는 긴 데이터는 손실됨
X_total = pad_sequences(X_total, maxlen = max_len)

# %% [markdown]
# # LSTM/GRU/BiLSTM 모델 훈련

# %%
# 필요한 프레임워크 및 라이브러리 임포트
from tensorflow.keras.layers import Embedding, Dense, GRU, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# 임베딩 벡터의 차원은 100으로, 리뷰분류를 위해 LSTM 사용
# 왜 100인지는 모름
model_LSTM = Sequential()
model_LSTM.add(Embedding(vocab_size+2, 100))
model_LSTM.add(LSTM(128))
model_LSTM.add(Dense(1, activation='sigmoid'))

# %%
model_GRU = Sequential()
model_GRU.add(Embedding(vocab_size+2, 100))
model_GRU.add(GRU(128))
model_GRU.add(Dense(1, activation='sigmoid'))

# %%
model_BiLSTM = Sequential()
model_BiLSTM.add(Embedding(vocab_size+2, 100))
model_BiLSTM.add(Bidirectional(LSTM(128)))
model_BiLSTM.add(Dense(1, activation='sigmoid'))

# %%
# 검증 데이터 손실이 4회 증가하면 학습 조기 종료
# model check point를 사용하여 검증 데이터의 정확도가 이전보다 좋아질 경우만 모델 저장
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc_LSTM = ModelCheckpoint('RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
mc_GRU = ModelCheckpoint('RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
mc_BiLSTM = ModelCheckpoint('RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
# 필요한 매트릭 선언, AUC-ROC, F1-Score, AUC-PR 에 필요한 지표 모두 체크
import tensorflow as tf

ROCauc = tf.keras.metrics.AUC(curve="ROC") # auc_1
PRauc = tf.keras.metrics.AUC(curve="PR") # auc_2
RECALL = tf.keras.metrics.Recall()
PRECISION = tf.keras.metrics.Precision()
TP = tf.keras.metrics.TruePositives()
TN = tf.keras.metrics.TrueNegatives()
FP = tf.keras.metrics.FalsePositives()
FN = tf.keras.metrics.FalseNegatives()

# %%
# LSTM모델 훈련
model_LSTM.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc', ROCauc, PRauc, RECALL, PRECISION, TP, TN, FP, FN])
history = model_LSTM.fit(X_total, y_total, epochs=15, callbacks=[es, mc_LSTM], batch_size=100, validation_split=0.2)
# Out:
# Epoch 1/15
# 3912/3912 [==============================] - 76s 16ms/step - loss: 0.3691 - acc: 0.8367 - auc: 0.9158 - auc_1: 0.9134 - recall: 0.8301 - precision: 0.8409 - true_positives: 162190.0000 - true_negatives: 165113.0000 - false_positives: 30686.0000 - false_negatives: 33198.0000 - val_loss: 0.3369 - val_acc: 0.8545 - val_auc: 0.9303 - val_auc_1: 0.9276 - val_recall: 0.8586 - val_precision: 0.8519 - val_true_positives: 42030.0000 - val_true_negatives: 41534.0000 - val_false_positives: 7309.0000 - val_false_negatives: 6924.0000
#
# Epoch 00001: val_acc improved from -inf to 0.85446, saving model to RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 2/15
# 3912/3912 [==============================] - 59s 15ms/step - loss: 0.3250 - acc: 0.8607 - auc: 0.9351 - auc_1: 0.9328 - recall: 0.8566 - precision: 0.8635 - true_positives: 167371.0000 - true_negatives: 169342.0000 - false_positives: 26457.0000 - false_negatives: 28017.0000 - val_loss: 0.3255 - val_acc: 0.8604 - val_auc: 0.9349 - val_auc_1: 0.9330 - val_recall: 0.8553 - val_precision: 0.8644 - val_true_positives: 41871.0000 - val_true_negatives: 42276.0000 - val_false_positives: 6567.0000 - val_false_negatives: 7083.0000
#
# Epoch 00002: val_acc improved from 0.85446 to 0.86043, saving model to RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 3/15
# 3912/3912 [==============================] - 59s 15ms/step - loss: 0.3107 - acc: 0.8687 - auc: 0.9408 - auc_1: 0.9389 - recall: 0.8658 - precision: 0.8706 - true_positives: 169174.0000 - true_negatives: 170646.0000 - false_positives: 25153.0000 - false_negatives: 26214.0000 - val_loss: 0.3190 - val_acc: 0.8646 - val_auc: 0.9375 - val_auc_1: 0.9355 - val_recall: 0.8642 - val_precision: 0.8652 - val_true_positives: 42305.0000 - val_true_negatives: 42249.0000 - val_false_positives: 6594.0000 - val_false_negatives: 6649.0000
#
# Epoch 00003: val_acc improved from 0.86043 to 0.86459, saving model to RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 4/15
# 3912/3912 [==============================] - 60s 15ms/step - loss: 0.3000 - acc: 0.8738 - auc: 0.9448 - auc_1: 0.9427 - recall: 0.8724 - precision: 0.8746 - true_positives: 170451.0000 - true_negatives: 171357.0000 - false_positives: 24442.0000 - false_negatives: 24937.0000 - val_loss: 0.3256 - val_acc: 0.8598 - val_auc: 0.9374 - val_auc_1: 0.9355 - val_recall: 0.8210 - val_precision: 0.8903 - val_true_positives: 40192.0000 - val_true_negatives: 43891.0000 - val_false_positives: 4952.0000 - val_false_negatives: 8762.0000
#
# Epoch 00004: val_acc did not improve from 0.86459
# Epoch 5/15
# 3912/3912 [==============================] - 59s 15ms/step - loss: 0.2907 - acc: 0.8787 - auc: 0.9482 - auc_1: 0.9463 - recall: 0.8780 - precision: 0.8791 - true_positives: 171552.0000 - true_negatives: 172200.0000 - false_positives: 23599.0000 - false_negatives: 23836.0000 - val_loss: 0.3191 - val_acc: 0.8655 - val_auc: 0.9383 - val_auc_1: 0.9370 - val_recall: 0.8575 - val_precision: 0.8718 - val_true_positives: 41977.0000 - val_true_negatives: 42671.0000 - val_false_positives: 6172.0000 - val_false_negatives: 6977.0000
#
# Epoch 00005: val_acc improved from 0.86459 to 0.86555, saving model to RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 6/15
# 3912/3912 [==============================] - 59s 15ms/step - loss: 0.2822 - acc: 0.8830 - auc: 0.9512 - auc_1: 0.9493 - recall: 0.8816 - precision: 0.8838 - true_positives: 172263.0000 - true_negatives: 173155.0000 - false_positives: 22644.0000 - false_negatives: 23125.0000 - val_loss: 0.3203 - val_acc: 0.8646 - val_auc: 0.9375 - val_auc_1: 0.9356 - val_recall: 0.8713 - val_precision: 0.8601 - val_true_positives: 42653.0000 - val_true_negatives: 41903.0000 - val_false_positives: 6940.0000 - val_false_negatives: 6301.0000
#
# Epoch 00006: val_acc did not improve from 0.86555
# Epoch 7/15
# 3912/3912 [==============================] - 59s 15ms/step - loss: 0.2732 - acc: 0.8875 - auc: 0.9542 - auc_1: 0.9526 - recall: 0.8872 - precision: 0.8876 - true_positives: 173345.0000 - true_negatives: 173837.0000 - false_positives: 21962.0000 - false_negatives: 22043.0000 - val_loss: 0.3212 - val_acc: 0.8647 - val_auc: 0.9377 - val_auc_1: 0.9351 - val_recall: 0.8512 - val_precision: 0.8750 - val_true_positives: 41672.0000 - val_true_negatives: 42890.0000 - val_false_positives: 5953.0000 - val_false_negatives: 7282.0000
#
# Epoch 00007: val_acc did not improve from 0.86555
# Epoch 00007: early stopping

# %%
# GRU모델 훈련
model_GRU.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc', ROCauc, PRauc, RECALL, PRECISION, TP, TN, FP, FN])
history = model_GRU.fit(X_total, y_total, epochs=15, callbacks=[es, mc_GRU], batch_size=100, validation_split=0.2)
# Out:
# Epoch 1/15
# 3912/3912 [==============================] - 64s 15ms/step - loss: 0.3653 - acc: 0.8392 - auc: 0.9217 - auc_1: 0.9192 - recall: 0.8366 - precision: 0.8495 - true_positives: 204409.0000 - true_negatives: 208420.0000 - false_positives: 36222.0000 - false_negatives: 39933.0000 - val_loss: 0.3371 - val_acc: 0.8545 - val_auc: 0.9311 - val_auc_1: 0.9293 - val_recall: 0.8367 - val_precision: 0.8680 - val_true_positives: 40960.0000 - val_true_negatives: 42612.0000 - val_false_positives: 6231.0000 - val_false_negatives: 7994.0000
#
# Epoch 00001: val_acc improved from -inf to 0.85455, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 2/15
# 3912/3912 [==============================] - 56s 14ms/step - loss: 0.3223 - acc: 0.8620 - auc: 0.9362 - auc_1: 0.9339 - recall: 0.8580 - precision: 0.8646 - true_positives: 167650.0000 - true_negatives: 169538.0000 - false_positives: 26261.0000 - false_negatives: 27738.0000 - val_loss: 0.3248 - val_acc: 0.8608 - val_auc: 0.9354 - val_auc_1: 0.9333 - val_recall: 0.8696 - val_precision: 0.8548 - val_true_positives: 42570.0000 - val_true_negatives: 41611.0000 - val_false_positives: 7232.0000 - val_false_negatives: 6384.0000
#
# Epoch 00002: val_acc improved from 0.85455 to 0.86077, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 3/15
# 3912/3912 [==============================] - 56s 14ms/step - loss: 0.3078 - acc: 0.8696 - auc: 0.9419 - auc_1: 0.9397 - recall: 0.8662 - precision: 0.8718 - true_positives: 169241.0000 - true_negatives: 170919.0000 - false_positives: 24880.0000 - false_negatives: 26147.0000 - val_loss: 0.3192 - val_acc: 0.8632 - val_auc: 0.9375 - val_auc_1: 0.9358 - val_recall: 0.8624 - val_precision: 0.8641 - val_true_positives: 42217.0000 - val_true_negatives: 42205.0000 - val_false_positives: 6638.0000 - val_false_negatives: 6737.0000
#
# Epoch 00003: val_acc improved from 0.86077 to 0.86324, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 4/15
# 3912/3912 [==============================] - 56s 14ms/step - loss: 0.2972 - acc: 0.8754 - auc: 0.9459 - auc_1: 0.9439 - recall: 0.8729 - precision: 0.8770 - true_positives: 170557.0000 - true_negatives: 171878.0000 - false_positives: 23921.0000 - false_negatives: 24831.0000 - val_loss: 0.3189 - val_acc: 0.8636 - val_auc: 0.9379 - val_auc_1: 0.9361 - val_recall: 0.8699 - val_precision: 0.8594 - val_true_positives: 42583.0000 - val_true_negatives: 41879.0000 - val_false_positives: 6964.0000 - val_false_negatives: 6371.0000
#
# Epoch 00004: val_acc improved from 0.86324 to 0.86365, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 5/15
# 3912/3912 [==============================] - 56s 14ms/step - loss: 0.2881 - acc: 0.8798 - auc: 0.9491 - auc_1: 0.9472 - recall: 0.8781 - precision: 0.8809 - true_positives: 171575.0000 - true_negatives: 172602.0000 - false_positives: 23197.0000 - false_negatives: 23813.0000 - val_loss: 0.3171 - val_acc: 0.8646 - val_auc: 0.9386 - val_auc_1: 0.9367 - val_recall: 0.8703 - val_precision: 0.8608 - val_true_positives: 42607.0000 - val_true_negatives: 41953.0000 - val_false_positives: 6890.0000 - val_false_negatives: 6347.0000
#
# Epoch 00005: val_acc improved from 0.86365 to 0.86465, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 6/15
# 3912/3912 [==============================] - 55s 14ms/step - loss: 0.2787 - acc: 0.8845 - auc: 0.9524 - auc_1: 0.9507 - recall: 0.8834 - precision: 0.8852 - true_positives: 172609.0000 - true_negatives: 173404.0000 - false_positives: 22395.0000 - false_negatives: 22779.0000 - val_loss: 0.3210 - val_acc: 0.8635 - val_auc: 0.9378 - val_auc_1: 0.9363 - val_recall: 0.8643 - val_precision: 0.8632 - val_true_positives: 42312.0000 - val_true_negatives: 42138.0000 - val_false_positives: 6705.0000 - val_false_negatives: 6642.0000
#
# Epoch 00006: val_acc did not improve from 0.86465
# Epoch 7/15
# 3912/3912 [==============================] - 57s 15ms/step - loss: 0.2695 - acc: 0.8891 - auc: 0.9555 - auc_1: 0.9539 - recall: 0.8884 - precision: 0.8894 - true_positives: 173577.0000 - true_negatives: 174209.0000 - false_positives: 21590.0000 - false_negatives: 21811.0000 - val_loss: 0.3261 - val_acc: 0.8625 - val_auc: 0.9371 - val_auc_1: 0.9354 - val_recall: 0.8527 - val_precision: 0.8700 - val_true_positives: 41741.0000 - val_true_negatives: 42608.0000 - val_false_positives: 6235.0000 - val_false_negatives: 7213.0000
#
# Epoch 00007: val_acc did not improve from 0.86465
# Epoch 8/15
# 3912/3912 [==============================] - 56s 14ms/step - loss: 0.2595 - acc: 0.8941 - auc: 0.9587 - auc_1: 0.9570 - recall: 0.8942 - precision: 0.8938 - true_positives: 174713.0000 - true_negatives: 175029.0000 - false_positives: 20770.0000 - false_negatives: 20675.0000 - val_loss: 0.3285 - val_acc: 0.8612 - val_auc: 0.9358 - val_auc_1: 0.9342 - val_recall: 0.8521 - val_precision: 0.8681 - val_true_positives: 41715.0000 - val_true_negatives: 42505.0000 - val_false_positives: 6338.0000 - val_false_negatives: 7239.0000
#
# Epoch 00008: val_acc did not improve from 0.86465
# Epoch 9/15
# 3912/3912 [==============================] - 55s 14ms/step - loss: 0.2488 - acc: 0.8996 - auc: 0.9619 - auc_1: 0.9604 - recall: 0.9002 - precision: 0.8989 - true_positives: 175892.0000 - true_negatives: 176023.0000 - false_positives: 19776.0000 - false_negatives: 19496.0000 - val_loss: 0.3344 - val_acc: 0.8591 - val_auc: 0.9341 - val_auc_1: 0.9321 - val_recall: 0.8616 - val_precision: 0.8575 - val_true_positives: 42177.0000 - val_true_negatives: 41836.0000 - val_false_positives: 7007.0000 - val_false_negatives: 6777.0000
#
# Epoch 00009: val_acc did not improve from 0.86465
# Epoch 00009: early stopping

# %%
# BiLSTM모델 훈련
model_BiLSTM.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc', ROCauc, PRauc, RECALL, PRECISION, TP, TN, FP, FN])
history = model_BiLSTM.fit(X_total, y_total, epochs=15, callbacks=[es, mc_BiLSTM], batch_size=100, validation_split=0.2)
# Out:
# Epoch 1/15
# 3912/3912 [==============================] - 89s 21ms/step - loss: 0.3699 - acc: 0.8363 - auc: 0.9189 - auc_1: 0.9164 - recall: 0.8359 - precision: 0.8440 - true_positives: 204252.0000 - true_negatives: 206900.0000 - false_positives: 37742.0000 - false_negatives: 40090.0000 - val_loss: 0.3377 - val_acc: 0.8537 - val_auc: 0.9302 - val_auc_1: 0.9280 - val_recall: 0.8542 - val_precision: 0.8536 - val_true_positives: 41817.0000 - val_true_negatives: 41669.0000 - val_false_positives: 7174.0000 - val_false_negatives: 7137.0000
#
# Epoch 00001: val_acc improved from -inf to 0.85367, saving model to RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 2/15
# 3912/3912 [==============================] - 78s 20ms/step - loss: 0.3256 - acc: 0.8606 - auc: 0.9349 - auc_1: 0.9326 - recall: 0.8555 - precision: 0.8641 - true_positives: 167150.0000 - true_negatives: 169514.0000 - false_positives: 26285.0000 - false_negatives: 28238.0000 - val_loss: 0.3270 - val_acc: 0.8605 - val_auc: 0.9348 - val_auc_1: 0.9330 - val_recall: 0.8543 - val_precision: 0.8653 - val_true_positives: 41822.0000 - val_true_negatives: 42332.0000 - val_false_positives: 6511.0000 - val_false_negatives: 7132.0000
#
# Epoch 00002: val_acc improved from 0.85367 to 0.86050, saving model to RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 3/15
# 3912/3912 [==============================] - 81s 21ms/step - loss: 0.3110 - acc: 0.8682 - auc: 0.9407 - auc_1: 0.9385 - recall: 0.8656 - precision: 0.8699 - true_positives: 169123.0000 - true_negatives: 170504.0000 - false_positives: 25295.0000 - false_negatives: 26265.0000 - val_loss: 0.3218 - val_acc: 0.8621 - val_auc: 0.9370 - val_auc_1: 0.9357 - val_recall: 0.8450 - val_precision: 0.8752 - val_true_positives: 41366.0000 - val_true_negatives: 42942.0000 - val_false_positives: 5901.0000 - val_false_negatives: 7588.0000
#
# Epoch 00003: val_acc improved from 0.86050 to 0.86207, saving model to RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 4/15
# 3912/3912 [==============================] - 76s 19ms/step - loss: 0.3003 - acc: 0.8738 - auc: 0.9447 - auc_1: 0.9427 - recall: 0.8720 - precision: 0.8750 - true_positives: 170376.0000 - true_negatives: 171459.0000 - false_positives: 24340.0000 - false_negatives: 25012.0000 - val_loss: 0.3192 - val_acc: 0.8630 - val_auc: 0.9376 - val_auc_1: 0.9361 - val_recall: 0.8462 - val_precision: 0.8760 - val_true_positives: 41423.0000 - val_true_negatives: 42980.0000 - val_false_positives: 5863.0000 - val_false_negatives: 7531.0000
#
# Epoch 00004: val_acc improved from 0.86207 to 0.86304, saving model to RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 5/15
# 3912/3912 [==============================] - 81s 21ms/step - loss: 0.2916 - acc: 0.8781 - auc: 0.9479 - auc_1: 0.9459 - recall: 0.8763 - precision: 0.8793 - true_positives: 171227.0000 - true_negatives: 172292.0000 - false_positives: 23507.0000 - false_negatives: 24161.0000 - val_loss: 0.3170 - val_acc: 0.8654 - val_auc: 0.9386 - val_auc_1: 0.9371 - val_recall: 0.8606 - val_precision: 0.8691 - val_true_positives: 42131.0000 - val_true_negatives: 42498.0000 - val_false_positives: 6345.0000 - val_false_negatives: 6823.0000
#
# Epoch 00005: val_acc improved from 0.86304 to 0.86535, saving model to RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 6/15
# 3912/3912 [==============================] - 77s 20ms/step - loss: 0.2829 - acc: 0.8826 - auc: 0.9510 - auc_1: 0.9492 - recall: 0.8822 - precision: 0.8826 - true_positives: 172378.0000 - true_negatives: 172869.0000 - false_positives: 22930.0000 - false_negatives: 23010.0000 - val_loss: 0.3202 - val_acc: 0.8659 - val_auc: 0.9386 - val_auc_1: 0.9367 - val_recall: 0.8684 - val_precision: 0.8644 - val_true_positives: 42514.0000 - val_true_negatives: 42172.0000 - val_false_positives: 6671.0000 - val_false_negatives: 6440.0000
#
# Epoch 00006: val_acc improved from 0.86535 to 0.86594, saving model to RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 7/15
# 3912/3912 [==============================] - 72s 18ms/step - loss: 0.2743 - acc: 0.8867 - auc: 0.9539 - auc_1: 0.9521 - recall: 0.8860 - precision: 0.8870 - true_positives: 173114.0000 - true_negatives: 173736.0000 - false_positives: 22063.0000 - false_negatives: 22274.0000 - val_loss: 0.3197 - val_acc: 0.8635 - val_auc: 0.9382 - val_auc_1: 0.9363 - val_recall: 0.8532 - val_precision: 0.8715 - val_true_positives: 41767.0000 - val_true_negatives: 42684.0000 - val_false_positives: 6159.0000 - val_false_negatives: 7187.0000
#
# Epoch 00007: val_acc did not improve from 0.86594
# Epoch 8/15
# 3912/3912 [==============================] - 74s 19ms/step - loss: 0.2655 - acc: 0.8918 - auc: 0.9568 - auc_1: 0.9551 - recall: 0.8914 - precision: 0.8919 - true_positives: 174172.0000 - true_negatives: 174691.0000 - false_positives: 21108.0000 - false_negatives: 21216.0000 - val_loss: 0.3236 - val_acc: 0.8633 - val_auc: 0.9374 - val_auc_1: 0.9356 - val_recall: 0.8522 - val_precision: 0.8718 - val_true_positives: 41718.0000 - val_true_negatives: 42707.0000 - val_false_positives: 6136.0000 - val_false_negatives: 7236.0000
#
# Epoch 00008: val_acc did not improve from 0.86594
# Epoch 9/15
# 3912/3912 [==============================] - 75s 19ms/step - loss: 0.2558 - acc: 0.8964 - auc: 0.9598 - auc_1: 0.9582 - recall: 0.8962 - precision: 0.8963 - true_positives: 175110.0000 - true_negatives: 175535.0000 - false_positives: 20264.0000 - false_negatives: 20278.0000 - val_loss: 0.3364 - val_acc: 0.8613 - val_auc: 0.9344 - val_auc_1: 0.9328 - val_recall: 0.8475 - val_precision: 0.8718 - val_true_positives: 41489.0000 - val_true_negatives: 42744.0000 - val_false_positives: 6099.0000 - val_false_negatives: 7465.0000
#
# Epoch 00009: val_acc did not improve from 0.86594
# Epoch 00009: early stopping

# %% [markdown]
# # LSTM/GRU/BiLSTM 모델 성능평가

# %%
# 평가용 토탈 데이터셋2(화장품+앱)

# 데이터 로드
total_data2 = pd.read_table('total_data(app&cosmetic).txt')

# 토크나이징
X_test_total2 = []
for sentence in total_data2['document']:
    temp_X2 = okt.morphs(sentence, stem=True)
    temp_X2 = [word for word in temp_X2 if not word in stopwords]
    X_test_total2.append(temp_X2)

# 워드 벡터화
tokenizer = Tokenizer(vocab_size)
tokenizer.fit_on_texts(X_test_total2)
X_test_total2 = tokenizer.texts_to_sequences(X_test_total2)

# 패딩
X_test_total2 = pad_sequences(X_test_total2, maxlen = max_len)

# 라벨데이터 포함
y_test_total2 = np.array(total_data2['label'])

# %%
# LSTM모델 성능 평가 
loaded_model = load_model('RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.h5')
result = loaded_model.evaluate(X_test_total2, y_test_total2, batch_size=100)
print("\n LSTM 테스트 결과:",result)
# Out:
# 107/107 [==============================] - 2s 7ms/step - loss: 1.1199 - acc: 0.4889 - auc: 0.5240 - auc_1: 0.7206 - recall: 0.4482 - precision: 0.7173 - true_positives: 3342.0000 - true_negatives: 1854.0000 - false_positives: 1317.0000 - false_negatives: 4114.0000
#
#  LSTM 테스트 결과: [1.1198639869689941, 0.4889432489871979, 0.5240488052368164, 0.7206312417984009, 0.4482296109199524, 0.7173213362693787, 3342.0, 1854.0, 1317.0, 4114.0]

# %%
# GRU모델 성능 평가 
loaded_model = load_model('RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.h5')
result = loaded_model.evaluate(X_test_total2, y_test_total2, batch_size=100)
print("\n GRU 테스트 결과:",result)
# Out:
# 107/107 [==============================] - 2s 6ms/step - loss: 0.9918 - acc: 0.5217 - auc: 0.5261 - auc_1: 0.7215 - recall: 0.5253 - precision: 0.7173 - true_positives: 3917.0000 - true_negatives: 1627.0000 - false_positives: 1544.0000 - false_negatives: 3539.0000
#
#  GRU 테스트 결과: [0.9917809367179871, 0.5216900110244751, 0.5260745286941528, 0.7215461730957031, 0.5253487229347229, 0.7172678709030151, 3917.0, 1627.0, 1544.0, 3539.0]

# %%
# BiLSTM모델 성능 평가 
loaded_model = load_model('RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.3.h5')
result = loaded_model.evaluate(X_test_total2, y_test_total2, batch_size=100)
print("\n BiLSTM 테스트 결과:",result)
# Out:
# 107/107 [==============================] - 2s 8ms/step - loss: 1.1561 - acc: 0.5036 - auc: 0.5204 - auc_1: 0.7186 - recall: 0.4914 - precision: 0.7119 - true_positives: 3664.0000 - true_negatives: 1688.0000 - false_positives: 1483.0000 - false_negatives: 3792.0000
#
#  BiLSTM 테스트 결과: [1.1561497449874878, 0.503622829914093, 0.5203986763954163, 0.718555212020874, 0.4914163053035736, 0.7118709683418274, 3664.0, 1688.0, 1483.0, 3792.0]
