# %% [markdown]
# # 데이터 로드

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 138kB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 10.9MB/s
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/98/88/f817ef1af6f794e8f11313dcd1549de833f4599abcec82746ab5ed086686/JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448kB)
#      |████████████████████████████████| 450kB 48.8MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Installing collected packages: beautifulsoup4, JPype1, colorama, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
# 필요 프레임워크 및 라이브러리 준비
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import re
import urllib.request
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# 사전에 정제+정규화된 훈련용 통합 데이터 로드
total_data = pd.read_table('total(movie+shopping+game)_data.txt')

# %%
# 통합 데이터 확인
print(len(total_data))
print(total_data[:3])
# Out:
# 489016
#                                             document  label
# 0                                        이유식 냄비로 좋아요      1
# 1                                       한글화가 없어서짜징난다      0
# 2  에휴 존나 뚝 뚝 끊키는대뭘게임을하라고 무슨 핑은좋은대 게임만들어가면 뚝뚝 끊키고 ...      0

# %% [markdown]
# # 토큰화

# %%
# 불용어 정의 (한국어 조사, 접속사 등) 18
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
# 훈련데이터에 형태소 분석기를 사용하여 토큰화를 하면서 불용어 제거
okt = Okt()
X_total = []
for sentence in total_data['document']:
    temp_X = okt.morphs(sentence, stem=True) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    X_total.append(temp_X)

# %%
print(len(X_total))
print(X_total[:3])
# Out:
# [['이유식', '냄비', '로', '좋다'], ['한글화', '없다', '짜다', '징', '난', '다'], ['휴', '존나', '뚝', '뚝', '끊다', '키', '대', '뭘', '게', '이다', '무슨', '핑', '좋다', '게임', '만', '들어가다', '뚝뚝', '끊다', '키', '고', '걸다', '괜찮다', '또', '총', '쏘다', '뚝뚝', '끊다', '키', '고', '해결', '법', '없다', '뭘', '게', '이다']]

# %% [markdown]
# # 정수 인코딩

# %%
# 기계가 텍스트를 숫자로 처리할 수 있도록 데이터를 정수로 변환
# 일단 단어 집합을 만들자
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_total)
 # fit_on_texts()안에 코퍼스를 입력으로 하면 빈도수를 기준으로 단어 집합을 생성한다.
 # 단어 빈도수가 높은순으로 낮은 정수 인덱스 부여

# %%
print(len(tokenizer.word_index))
print(tokenizer.word_index)
print(tokenizer.word_counts)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# 등장 빈도수가 낮은 데이터를 처리해보자
# 특정 횟수 이하 단어의 비중이 몇인지 체크
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 85794
# 등장 빈도가 2번 이하인 희귀 단어의 수: 50413
# 단어 집합에서 희귀 단어의 비율: 58.76051938363989
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.016628619931301

# %%
# 전체 단어 개수 중 빈도수 12이하인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 35382

# %%
# 단어집합을 케라스 토크나이저의 인자로 넘겨주면, 케라스 토크나이저는 텍스트 시퀀스를 숫자 시퀀스로 변환
tokenizer = Tokenizer(vocab_size) 
tokenizer.fit_on_texts(X_total)
X_total = tokenizer.texts_to_sequences(X_total)

# %%
print(X_total[:3])
# Out:
# [[2732, 4498, 15, 2], [710, 7, 264, 2506, 241, 12], [950, 425, 5133, 5133, 2075, 355, 200, 609, 51, 9, 253, 1508, 2, 8, 19, 267, 3338, 2075, 355, 30, 672, 79, 132, 558, 780, 3338, 2075, 355, 30, 982, 1310, 7, 609, 51, 9]]

# %%
y_total = np.array(total_data['label'])

# %% [markdown]
# # 빈 샘플(empty samples)제거

# %%
# 각 샘플의 길이가 0인 샘플들의 인덱스 확인
drop_total = [index for index, sentence in enumerate(X_total) if len(sentence) < 1]
print(drop_total)
# Out:
# [276, 307, 547, 796, 1120, 1373, 2343, 2986, 4228, 5097, 5109, 6781, 12156, 12380, 13388, 13531, 14632, 14928, 15550, 16844, 17257, 17852, 19313, 21575, 21628, 21964, 23852, 27170, 27545, 28289, 28523, 29113, 29211, 29382, 30843, 31175, 32099, 33805, 34424, 35084, 35415, 36367, 36630, 37159, 37436, 38539, 38550, 38985, 39823, 39859, 40432, 42212, 42361, 42896, 44802, 45031, 48040, 48880, 49252, 50511, 50533, 50921, 50946, 52285, 52921, 53875, 54153, 58382, 58594, 58710, 58715, 59266, 59343, 62103, 62772, 63518, 64722, 64813, 65123, 68701, 68847, 69519, 69850, 69862, 69886, 70307, 71458, 71509, 73025, 75950, 76777, 78879, 79566, 79994, 81020, 82187, 87152, 87519, 88014, 89307, 89351, 90202, 90440, 91204, 91964, 92389, 92988, 93739, 93891, 94613, 95566, 96166, 97801, 98887, 99571, 99679, 99823, 101599, 101937, 101993, 102131, 102544, 102761, 103957, 105816, 106600, 107573, 108803, 113450, 113468, 114738, 114766, 114939, 114946, 115384, 117534, 118058, 118472, 118548, 119034, 119292, 120217, 120604, 120823, 121425, 122328, 122681, 124295, 124509, 124595, 125018, 126973, 127220, 127383, 131275, 131447, 132230, 132506, 135779, 138189, 139665, 141845, 144515, 145521, 145702, 148509, 149552, 149840, 152212, 152446, 152900, 153491, 156737, 157444, 158166, 159836, 160246, 161945, 162022, 162833, 162997, 163890, 164436, 164721, 165427, 167609, 168731, 170209, 172221, 173666, 174881, 175692, 177424, 177737, 178070, 178419, 179435, 179494, 180587, 181049, 181966, 182306, 182507, 182876, 183863, 184360, 186146, 187775, 188918, 189176, 189242, 191427, 192428, 193272, 194661, 195019, 198198, 199238, 199771, 201609, 203582, 203881, 205211, 205884, 206148, 208609, 208717, 209884, 211883, 214116, 214641, 214948, 215234, 215372, 215387, 215968, 217315, 217613, 217997, 218236, 219775, 220324, 221037, 222349, 223176, 229078, 230727, 231251, 233655, 235381, 236046, 236933, 237207, 237710, 237730, 239681, 242285, 242341, 242423, 246501, 246668, 246691, 248107, 249553, 250419, 250482, 250585, 251110, 254318, 254812, 254978, 258207, 258607, 259996, 260844, 261718, 262171, 263465, 264148, 265504, 265804, 267170, 269253, 270663, 271488, 272198, 272606, 274122, 274661, 275749, 275924, 277052, 279409, 279557, 281303, 281331, 281365, 282033, 282796, 284342, 284469, 288124, 289476, 289532, 290606, 290872, 291902, 294272, 294473, 294695, 296722, 296784, 296914, 300609, 300717, 300769, 301146, 301256, 301993, 305370, 305983, 306511, 307117, 307299, 308768, 309414, 309928, 310944, 311021, 311275, 311349, 312929, 312946, 313077, 313234, 314700, 315452, 316304, 316358, 316522, 317751, 318774, 318979, 319322, 320221, 320596, 321158, 322537, 324397, 324434, 324493, 324951, 325680, 326323, 326757, 327521, 328376, 329372, 329483, 330614, 330619, 331880, 332754, 333782, 334417, 335516, 336215, 336657, 338388, 338908, 339323, 340065, 340070, 340566, 341320, 341437, 342754, 343477, 344055, 345260, 345483, 346064, 349519, 351479, 352362, 352440, 352591, 352638, 353866, 353960, 353989, 354065, 354870, 356026, 356896, 358988, 360285, 362008, 362128, 362385, 363465, 363595, 364545, 365482, 365842, 366742, 366813, 368196, 368326, 368487, 368510, 368680, 368844, 369407, 369785, 372053, 372175, 372223, 372326, 373885, 374272, 374858, 377290, 378442, 379499, 380372, 383663, 384948, 386236, 387357, 389177, 389283, 389590, 391249, 392245, 392273, 393076, 393346, 393485, 393802, 394581, 395105, 395815, 396464, 396776, 397170, 397405, 398654, 400513, 401034, 401713, 402620, 403856, 406899, 407576, 407792, 408143, 408171, 408364, 408784, 409542, 409554, 410292, 410415, 410914, 411093, 411145, 411891, 412250, 413017, 415432, 415666, 415774, 417881, 418169, 418479, 418726, 419696, 420831, 421887, 422217, 423415, 424034, 424785, 425247, 425856, 426728, 426840, 427113, 427147, 428348, 430774, 431991, 433481, 433980, 434682, 434773, 434785, 435149, 436273, 436941, 437369, 437993, 438184, 438338, 438913, 439572, 441196, 441758, 442562, 442956, 443073, 443738, 444168, 444580, 445727, 4460 ...

# %%
# 빈 샘플들을 제거
X_total = np.delete(X_total, drop_total, axis=0)
y_total = np.delete(y_total, drop_total, axis=0)
print(len(X_total))
print(len(y_total))
# Out:
# 488447
# 488447
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # 패딩

# %%
# 서로 다른 길이의 샘플들의 길이를 동일하게 맞춰는 작업
# 전체 데이터에서 가장 길이가 긴 리뷰와, 전체의 길이분포를 알아보자
print('리뷰의 최대 길이 :',max(len(l) for l in X_total))
print('리뷰의 평균 길이 :',sum(map(len, X_total))/len(X_total))
plt.hist([len(s) for s in X_total], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 69
# 리뷰의 평균 길이 : 11.978009896672516

# %%
# 최적의 길이를 찾기 위해, 전체 샘플중 길이가 max_len 이하인 샘플의 비율을 확인하는 함수 생성
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
# 30 이하 비율 체크
max_len = 30
below_threshold_len(max_len, X_total)
# Out:
# 전체 샘플 중 길이가 30 이하인 샘플의 비율: 93.6846781738858

# %%
# 짧은 데이터는 0을 채우고, 30을 넘는 긴 데이터는 손실됨
X_total = pad_sequences(X_total, maxlen = max_len)

# %% [markdown]
# # LSTM/GRU/BiLSTM 모델 훈련

# %%
# 필요한 프레임워크 및 라이브러리 임포트
from tensorflow.keras.layers import Embedding, Dense, GRU, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# 임베딩 벡터의 차원은 100으로, 리뷰분류를 위해 LSTM 사용
# 왜 100인지는 모름
model_LSTM = Sequential()
model_LSTM.add(Embedding(vocab_size, 100))
model_LSTM.add(LSTM(128))
model_LSTM.add(Dense(1, activation='sigmoid'))

# %%
model_GRU = Sequential()
model_GRU.add(Embedding(vocab_size, 100))
model_GRU.add(GRU(128))
model_GRU.add(Dense(1, activation='sigmoid'))

# %%
model_BiLSTM = Sequential()
model_BiLSTM.add(Embedding(vocab_size, 100))
model_BiLSTM.add(Bidirectional(LSTM(128)))
model_BiLSTM.add(Dense(1, activation='sigmoid'))

# %%
# 검증 데이터 손실이 4회 증가하면 학습 조기 종료
# model check point를 사용하여 검증 데이터의 정확도가 이전보다 좋아질 경우만 모델 저장
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc_LSTM = ModelCheckpoint('RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
mc_GRU = ModelCheckpoint('RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
mc_BiLSTM = ModelCheckpoint('RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
# 필요한 매트릭 선언, AUC-ROC, F1-Score, AUC-PR 에 필요한 지표 모두 체크
import tensorflow as tf

ROCauc = tf.keras.metrics.AUC(curve="ROC") # auc_1
PRauc = tf.keras.metrics.AUC(curve="PR") # auc_2
RECALL = tf.keras.metrics.Recall()
PRECISION = tf.keras.metrics.Precision()
TP = tf.keras.metrics.TruePositives()
TN = tf.keras.metrics.TrueNegatives()
FP = tf.keras.metrics.FalsePositives()
FN = tf.keras.metrics.FalseNegatives()

# %%
# LSTM모델 훈련
model_LSTM.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc', ROCauc, PRauc, RECALL, PRECISION, TP, TN, FP, FN])
history = model_LSTM.fit(X_total, y_total, epochs=15, callbacks=[es, mc_LSTM], batch_size=100, validation_split=0.2)
# Out:
# Epoch 1/15
# 3908/3908 [==============================] - 87s 21ms/step - loss: 0.3671 - acc: 0.8387 - auc_2: 0.9167 - auc_3: 0.9139 - recall_1: 0.8319 - precision_1: 0.8431 - true_positives_1: 162328.0000 - true_negatives_1: 165404.0000 - false_positives_1: 30215.0000 - false_negatives_1: 32810.0000 - val_loss: 0.3348 - val_acc: 0.8568 - val_auc_2: 0.9314 - val_auc_3: 0.9295 - val_recall_1: 0.8436 - val_precision_1: 0.8667 - val_true_positives_1: 41240.0000 - val_true_negatives_1: 42457.0000 - val_false_positives_1: 6345.0000 - val_false_negatives_1: 7648.0000
#
# Epoch 00001: val_acc improved from -inf to 0.85676, saving model to RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 2/15
# 3908/3908 [==============================] - 85s 22ms/step - loss: 0.3201 - acc: 0.8646 - auc_2: 0.9371 - auc_3: 0.9347 - recall_1: 0.8601 - precision_1: 0.8677 - true_positives_1: 167830.0000 - true_negatives_1: 170037.0000 - false_positives_1: 25582.0000 - false_negatives_1: 27308.0000 - val_loss: 0.3239 - val_acc: 0.8632 - val_auc_2: 0.9361 - val_auc_3: 0.9342 - val_recall_1: 0.8734 - val_precision_1: 0.8562 - val_true_positives_1: 42700.0000 - val_true_negatives_1: 41629.0000 - val_false_positives_1: 7173.0000 - val_false_negatives_1: 6188.0000
#
# Epoch 00002: val_acc improved from 0.85676 to 0.86323, saving model to RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 3/15
# 3908/3908 [==============================] - 85s 22ms/step - loss: 0.3014 - acc: 0.8747 - auc_2: 0.9443 - auc_3: 0.9422 - recall_1: 0.8708 - precision_1: 0.8773 - true_positives_1: 169934.0000 - true_negatives_1: 171855.0000 - false_positives_1: 23764.0000 - false_negatives_1: 25204.0000 - val_loss: 0.3164 - val_acc: 0.8656 - val_auc_2: 0.9386 - val_auc_3: 0.9369 - val_recall_1: 0.8621 - val_precision_1: 0.8684 - val_true_positives_1: 42147.0000 - val_true_negatives_1: 42417.0000 - val_false_positives_1: 6385.0000 - val_false_negatives_1: 6741.0000
#
# Epoch 00003: val_acc improved from 0.86323 to 0.86564, saving model to RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 4/15
# 3908/3908 [==============================] - 84s 22ms/step - loss: 0.2873 - acc: 0.8821 - auc_2: 0.9493 - auc_3: 0.9473 - recall_1: 0.8788 - precision_1: 0.8843 - true_positives_1: 171496.0000 - true_negatives_1: 173175.0000 - false_positives_1: 22444.0000 - false_negatives_1: 23642.0000 - val_loss: 0.3196 - val_acc: 0.8664 - val_auc_2: 0.9383 - val_auc_3: 0.9359 - val_recall_1: 0.8622 - val_precision_1: 0.8697 - val_true_positives_1: 42152.0000 - val_true_negatives_1: 42488.0000 - val_false_positives_1: 6314.0000 - val_false_negatives_1: 6736.0000
#
# Epoch 00004: val_acc improved from 0.86564 to 0.86641, saving model to RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 5/15
# 3908/3908 [==============================] - 84s 22ms/step - loss: 0.2750 - acc: 0.8877 - auc_2: 0.9535 - auc_3: 0.9518 - recall_1: 0.8846 - precision_1: 0.8899 - true_positives_1: 172616.0000 - true_negatives_1: 174267.0000 - false_positives_1: 21352.0000 - false_negatives_1: 22522.0000 - val_loss: 0.3186 - val_acc: 0.8663 - val_auc_2: 0.9389 - val_auc_3: 0.9371 - val_recall_1: 0.8609 - val_precision_1: 0.8705 - val_true_positives_1: 42089.0000 - val_true_negatives_1: 42541.0000 - val_false_positives_1: 6261.0000 - val_false_negatives_1: 6799.0000
#
# Epoch 00005: val_acc did not improve from 0.86641
# Epoch 6/15
# 3908/3908 [==============================] - 83s 21ms/step - loss: 0.2635 - acc: 0.8939 - auc_2: 0.9573 - auc_3: 0.9556 - recall_1: 0.8917 - precision_1: 0.8954 - true_positives_1: 174000.0000 - true_negatives_1: 175292.0000 - false_positives_1: 20327.0000 - false_negatives_1: 21138.0000 - val_loss: 0.3202 - val_acc: 0.8648 - val_auc_2: 0.9379 - val_auc_3: 0.9365 - val_recall_1: 0.8514 - val_precision_1: 0.8751 - val_true_positives_1: 41621.0000 - val_true_negatives_1: 42860.0000 - val_false_positives_1: 5942.0000 - val_false_negatives_1: 7267.0000
#
# Epoch 00006: val_acc did not improve from 0.86641
# Epoch 7/15
# 3908/3908 [==============================] - 82s 21ms/step - loss: 0.2510 - acc: 0.8999 - auc_2: 0.9611 - auc_3: 0.9596 - recall_1: 0.8985 - precision_1: 0.9009 - true_positives_1: 175326.0000 - true_negatives_1: 176330.0000 - false_positives_1: 19289.0000 - false_negatives_1: 19812.0000 - val_loss: 0.3298 - val_acc: 0.8621 - val_auc_2: 0.9363 - val_auc_3: 0.9348 - val_recall_1: 0.8689 - val_precision_1: 0.8575 - val_true_positives_1: 42479.0000 - val_true_negatives_1: 41740.0000 - val_false_positives_1: 7062.0000 - val_false_negatives_1: 6409.0000
#
# Epoch 00007: val_acc did not improve from 0.86641
# Epoch 00007: early stopping

# %%
# GRU모델 훈련
model_GRU.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc', ROCauc, PRauc, RECALL, PRECISION, TP, TN, FP, FN])
history = model_GRU.fit(X_total, y_total, epochs=15, callbacks=[es, mc_GRU], batch_size=100, validation_split=0.2)
# Out:
# Epoch 1/15
# 3908/3908 [==============================] - 92s 22ms/step - loss: 0.3650 - acc: 0.8400 - auc_2: 0.9211 - auc_3: 0.9188 - recall_1: 0.8410 - precision_1: 0.8466 - true_positives_1: 205223.0000 - true_negatives_1: 207236.0000 - false_positives_1: 37185.0000 - false_negatives_1: 38803.0000 - val_loss: 0.3360 - val_acc: 0.8556 - val_auc_2: 0.9307 - val_auc_3: 0.9290 - val_recall_1: 0.8428 - val_precision_1: 0.8652 - val_true_positives_1: 41203.0000 - val_true_negatives_1: 42380.0000 - val_false_positives_1: 6422.0000 - val_false_negatives_1: 7685.0000
#
# Epoch 00001: val_acc improved from -inf to 0.85559, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 2/15
# 3908/3908 [==============================] - 83s 21ms/step - loss: 0.3180 - acc: 0.8663 - auc_2: 0.9379 - auc_3: 0.9357 - recall_1: 0.8621 - precision_1: 0.8691 - true_positives_1: 168223.0000 - true_negatives_1: 170293.0000 - false_positives_1: 25326.0000 - false_negatives_1: 26915.0000 - val_loss: 0.3217 - val_acc: 0.8640 - val_auc_2: 0.9365 - val_auc_3: 0.9350 - val_recall_1: 0.8555 - val_precision_1: 0.8705 - val_true_positives_1: 41822.0000 - val_true_negatives_1: 42583.0000 - val_false_positives_1: 6219.0000 - val_false_negatives_1: 7066.0000
#
# Epoch 00002: val_acc improved from 0.85559 to 0.86401, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 3/15
# 3908/3908 [==============================] - 82s 21ms/step - loss: 0.2980 - acc: 0.8766 - auc_2: 0.9455 - auc_3: 0.9435 - recall_1: 0.8728 - precision_1: 0.8793 - true_positives_1: 170314.0000 - true_negatives_1: 172231.0000 - false_positives_1: 23388.0000 - false_negatives_1: 24824.0000 - val_loss: 0.3215 - val_acc: 0.8656 - val_auc_2: 0.9382 - val_auc_3: 0.9365 - val_recall_1: 0.8734 - val_precision_1: 0.8601 - val_true_positives_1: 42701.0000 - val_true_negatives_1: 41858.0000 - val_false_positives_1: 6944.0000 - val_false_negatives_1: 6187.0000
#
# Epoch 00003: val_acc improved from 0.86401 to 0.86559, saving model to RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 4/15
# 3908/3908 [==============================] - 81s 21ms/step - loss: 0.2833 - acc: 0.8838 - auc_2: 0.9507 - auc_3: 0.9490 - recall_1: 0.8809 - precision_1: 0.8859 - true_positives_1: 171893.0000 - true_negatives_1: 173470.0000 - false_positives_1: 22149.0000 - false_negatives_1: 23245.0000 - val_loss: 0.3204 - val_acc: 0.8635 - val_auc_2: 0.9390 - val_auc_3: 0.9377 - val_recall_1: 0.8308 - val_precision_1: 0.8892 - val_true_positives_1: 40617.0000 - val_true_negatives_1: 43742.0000 - val_false_positives_1: 5060.0000 - val_false_negatives_1: 8271.0000
#
# Epoch 00004: val_acc did not improve from 0.86559
# Epoch 5/15
# 3908/3908 [==============================] - 82s 21ms/step - loss: 0.2703 - acc: 0.8904 - auc_2: 0.9551 - auc_3: 0.9533 - recall_1: 0.8882 - precision_1: 0.8918 - true_positives_1: 173316.0000 - true_negatives_1: 174599.0000 - false_positives_1: 21020.0000 - false_negatives_1: 21822.0000 - val_loss: 0.3218 - val_acc: 0.8639 - val_auc_2: 0.9376 - val_auc_3: 0.9361 - val_recall_1: 0.8609 - val_precision_1: 0.8663 - val_true_positives_1: 42086.0000 - val_true_negatives_1: 42309.0000 - val_false_positives_1: 6493.0000 - val_false_negatives_1: 6802.0000
#
# Epoch 00005: val_acc did not improve from 0.86559
# Epoch 6/15
# 3908/3908 [==============================] - 80s 20ms/step - loss: 0.2572 - acc: 0.8966 - auc_2: 0.9593 - auc_3: 0.9576 - recall_1: 0.8950 - precision_1: 0.8976 - true_positives_1: 174656.0000 - true_negatives_1: 175699.0000 - false_positives_1: 19920.0000 - false_negatives_1: 20482.0000 - val_loss: 0.3241 - val_acc: 0.8619 - val_auc_2: 0.9364 - val_auc_3: 0.9347 - val_recall_1: 0.8515 - val_precision_1: 0.8698 - val_true_positives_1: 41630.0000 - val_true_negatives_1: 42569.0000 - val_false_positives_1: 6233.0000 - val_false_negatives_1: 7258.0000
#
# Epoch 00006: val_acc did not improve from 0.86559
# Epoch 7/15
# 3908/3908 [==============================] - 80s 20ms/step - loss: 0.2447 - acc: 0.9027 - auc_2: 0.9630 - auc_3: 0.9614 - recall_1: 0.9015 - precision_1: 0.9034 - true_positives_1: 175925.0000 - true_negatives_1: 176808.0000 - false_positives_1: 18811.0000 - false_negatives_1: 19213.0000 - val_loss: 0.3300 - val_acc: 0.8610 - val_auc_2: 0.9353 - val_auc_3: 0.9335 - val_recall_1: 0.8634 - val_precision_1: 0.8594 - val_true_positives_1: 42211.0000 - val_true_negatives_1: 41899.0000 - val_false_positives_1: 6903.0000 - val_false_negatives_1: 6677.0000
#
# Epoch 00007: val_acc did not improve from 0.86559
# Epoch 8/15
# 3908/3908 [==============================] - 80s 20ms/step - loss: 0.2310 - acc: 0.9089 - auc_2: 0.9669 - auc_3: 0.9654 - recall_1: 0.9086 - precision_1: 0.9090 - true_positives_1: 177305.0000 - true_negatives_1: 177868.0000 - false_positives_1: 17751.0000 - false_negatives_1: 17833.0000 - val_loss: 0.3411 - val_acc: 0.8592 - val_auc_2: 0.9332 - val_auc_3: 0.9316 - val_recall_1: 0.8616 - val_precision_1: 0.8577 - val_true_positives_1: 42123.0000 - val_true_negatives_1: 41813.0000 - val_false_positives_1: 6989.0000 - val_false_negatives_1: 6765.0000
#
# Epoch 00008: val_acc did not improve from 0.86559
# Epoch 00008: early stopping

# %%
# BiLSTM모델 훈련
model_BiLSTM.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc', ROCauc, PRauc, RECALL, PRECISION, TP, TN, FP, FN])
history = model_BiLSTM.fit(X_total, y_total, epochs=15, callbacks=[es, mc_BiLSTM], batch_size=100, validation_split=0.2)
# Out:
# Epoch 1/15
# 3908/3908 [==============================] - 110s 26ms/step - loss: 0.3679 - acc: 0.8379 - auc_2: 0.9191 - auc_3: 0.9166 - recall_1: 0.8365 - precision_1: 0.8459 - true_positives_1: 204131.0000 - true_negatives_1: 207234.0000 - false_positives_1: 37187.0000 - false_negatives_1: 39895.0000 - val_loss: 0.3388 - val_acc: 0.8544 - val_auc_2: 0.9304 - val_auc_3: 0.9278 - val_recall_1: 0.8267 - val_precision_1: 0.8755 - val_true_positives_1: 40414.0000 - val_true_negatives_1: 43054.0000 - val_false_positives_1: 5748.0000 - val_false_negatives_1: 8474.0000
#
# Epoch 00001: val_acc improved from -inf to 0.85442, saving model to RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 2/15
# 3908/3908 [==============================] - 100s 26ms/step - loss: 0.3208 - acc: 0.8644 - auc_2: 0.9368 - auc_3: 0.9344 - recall_1: 0.8592 - precision_1: 0.8679 - true_positives_1: 167664.0000 - true_negatives_1: 170100.0000 - false_positives_1: 25519.0000 - false_negatives_1: 27474.0000 - val_loss: 0.3270 - val_acc: 0.8613 - val_auc_2: 0.9348 - val_auc_3: 0.9331 - val_recall_1: 0.8427 - val_precision_1: 0.8755 - val_true_positives_1: 41198.0000 - val_true_negatives_1: 42942.0000 - val_false_positives_1: 5860.0000 - val_false_negatives_1: 7690.0000
#
# Epoch 00002: val_acc improved from 0.85442 to 0.86130, saving model to RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 3/15
# 3908/3908 [==============================] - 98s 25ms/step - loss: 0.3028 - acc: 0.8743 - auc_2: 0.9437 - auc_3: 0.9417 - recall_1: 0.8700 - precision_1: 0.8773 - true_positives_1: 169762.0000 - true_negatives_1: 171873.0000 - false_positives_1: 23746.0000 - false_negatives_1: 25376.0000 - val_loss: 0.3231 - val_acc: 0.8651 - val_auc_2: 0.9374 - val_auc_3: 0.9354 - val_recall_1: 0.8639 - val_precision_1: 0.8662 - val_true_positives_1: 42232.0000 - val_true_negatives_1: 42278.0000 - val_false_positives_1: 6524.0000 - val_false_negatives_1: 6656.0000
#
# Epoch 00003: val_acc improved from 0.86130 to 0.86508, saving model to RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 4/15
# 3908/3908 [==============================] - 100s 26ms/step - loss: 0.2886 - acc: 0.8813 - auc_2: 0.9489 - auc_3: 0.9468 - recall_1: 0.8780 - precision_1: 0.8836 - true_positives_1: 171334.0000 - true_negatives_1: 173048.0000 - false_positives_1: 22571.0000 - false_negatives_1: 23804.0000 - val_loss: 0.3215 - val_acc: 0.8654 - val_auc_2: 0.9389 - val_auc_3: 0.9375 - val_recall_1: 0.8412 - val_precision_1: 0.8842 - val_true_positives_1: 41123.0000 - val_true_negatives_1: 43415.0000 - val_false_positives_1: 5387.0000 - val_false_negatives_1: 7765.0000
#
# Epoch 00004: val_acc improved from 0.86508 to 0.86537, saving model to RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5
# Epoch 5/15
# 3908/3908 [==============================] - 99s 25ms/step - loss: 0.2764 - acc: 0.8874 - auc_2: 0.9531 - auc_3: 0.9513 - recall_1: 0.8851 - precision_1: 0.8889 - true_positives_1: 172709.0000 - true_negatives_1: 174043.0000 - false_positives_1: 21576.0000 - false_negatives_1: 22429.0000 - val_loss: 0.3211 - val_acc: 0.8626 - val_auc_2: 0.9379 - val_auc_3: 0.9366 - val_recall_1: 0.8392 - val_precision_1: 0.8807 - val_true_positives_1: 41026.0000 - val_true_negatives_1: 43245.0000 - val_false_positives_1: 5557.0000 - val_false_negatives_1: 7862.0000
#
# Epoch 00005: val_acc did not improve from 0.86537
# Epoch 6/15
# 3908/3908 [==============================] - 96s 25ms/step - loss: 0.2653 - acc: 0.8931 - auc_2: 0.9567 - auc_3: 0.9550 - recall_1: 0.8915 - precision_1: 0.8941 - true_positives_1: 173970.0000 - true_negatives_1: 175017.0000 - false_positives_1: 20602.0000 - false_negatives_1: 21168.0000 - val_loss: 0.3188 - val_acc: 0.8654 - val_auc_2: 0.9383 - val_auc_3: 0.9368 - val_recall_1: 0.8683 - val_precision_1: 0.8634 - val_true_positives_1: 42451.0000 - val_true_negatives_1: 42087.0000 - val_false_positives_1: 6715.0000 - val_false_negatives_1: 6437.0000
#
# Epoch 00006: val_acc did not improve from 0.86537
# Epoch 7/15
# 3908/3908 [==============================] - 100s 26ms/step - loss: 0.2543 - acc: 0.8986 - auc_2: 0.9601 - auc_3: 0.9585 - recall_1: 0.8971 - precision_1: 0.8994 - true_positives_1: 175068.0000 - true_negatives_1: 176047.0000 - false_positives_1: 19572.0000 - false_negatives_1: 20070.0000 - val_loss: 0.3327 - val_acc: 0.8631 - val_auc_2: 0.9370 - val_auc_3: 0.9355 - val_recall_1: 0.8699 - val_precision_1: 0.8585 - val_true_positives_1: 42530.0000 - val_true_negatives_1: 41791.0000 - val_false_positives_1: 7011.0000 - val_false_negatives_1: 6358.0000
#
# Epoch 00007: val_acc did not improve from 0.86537
# Epoch 8/15
# 3908/3908 [==============================] - 98s 25ms/step - loss: 0.2430 - acc: 0.9039 - auc_2: 0.9635 - auc_3: 0.9621 - recall_1: 0.9034 - precision_1: 0.9040 - true_positives_1: 176291.0000 - true_negatives_1: 176898.0000 - false_positives_1: 18721.0000 - false_negatives_1: 18847.0000 - val_loss: 0.3310 - val_acc: 0.8625 - val_auc_2: 0.9357 - val_auc_3: 0.9336 - val_recall_1: 0.8714 - val_precision_1: 0.8563 - val_true_positives_1: 42599.0000 - val_true_negatives_1: 41654.0000 - val_false_positives_1: 7148.0000 - val_false_negatives_1: 6289.0000
#
# Epoch 00008: val_acc did not improve from 0.86537
# Epoch 9/15
# 3908/3908 [==============================] - 97s 25ms/step - loss: 0.2312 - acc: 0.9090 - auc_2: 0.9669 - auc_3: 0.9654 - recall_1: 0.9091 - precision_1: 0.9086 - true_positives_1: 177403.0000 - true_negatives_1: 177784.0000 - false_positives_1: 17835.0000 - false_negatives_1: 17735.0000 - val_loss: 0.3390 - val_acc: 0.8614 - val_auc_2: 0.9336 - val_auc_3: 0.9304 - val_recall_1: 0.8621 - val_precision_1: 0.8611 - val_true_positives_1: 42144.0000 - val_true_negatives_1: 42005.0000 - val_false_positives_1: 6797.0000 - val_false_negatives_1: 6744.0000
#
# Epoch 00009: val_acc did not improve from 0.86537
# Epoch 10/15
# 3908/3908 [==============================] - 99s 25ms/step - loss: 0.2188 - acc: 0.9147 - auc_2: 0.9702 - auc_3: 0.9689 - recall_1: 0.9151 - precision_1: 0.9142 - true_positives_1: 178569.0000 - true_negatives_1: 178862.0000 - false_positives_1: 16757.0000 - false_negatives_1: 16569.0000 - val_loss: 0.3563 - val_acc: 0.8555 - val_auc_2: 0.9302 - val_auc_3: 0.9274 - val_recall_1: 0.8367 - val_precision_1: 0.8697 - val_true_positives_1: 40903.0000 - val_true_negatives_1: 42672.0000 - val_false_positives_1: 6130.0000 - val_false_negatives_1: 7985.0000
#
# Epoch 00010: val_acc did not improve from 0.86537
# Epoch 00010: early stopping

# %% [markdown]
# # LSTM/GRU/BiLSTM 모델 성능평가

# %%
# 평가용 토탈 데이터셋2(화장품+앱)

# 데이터 로드
total_data2 = pd.read_table('total_data(app&cosmetic).txt')

# 토크나이징
X_test_total2 = []
for sentence in total_data2['document']:
    temp_X2 = okt.morphs(sentence, stem=True)
    temp_X2 = [word for word in temp_X2 if not word in stopwords]
    X_test_total2.append(temp_X2)

# 워드 벡터화
tokenizer = Tokenizer(vocab_size)
tokenizer.fit_on_texts(X_test_total2)
X_test_total2 = tokenizer.texts_to_sequences(X_test_total2)

# 패딩
X_test_total2 = pad_sequences(X_test_total2, maxlen = max_len)

# 라벨데이터 포함
y_test_total2 = np.array(total_data2['label'])

# %%
# LSTM모델 성능 평가 
loaded_model = load_model('RNN_LSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5')
result = loaded_model.evaluate(X_test_total2, y_test_total2, batch_size=100)
print("\n LSTM 테스트 결과:",result)
# Out:
# 107/107 [==============================] - 2s 7ms/step - loss: 1.0711 - acc: 0.5170 - auc_2: 0.5164 - auc_3: 0.7152 - recall_1: 0.5318 - precision_1: 0.7072 - true_positives_1: 3965.0000 - true_negatives_1: 1529.0000 - false_positives_1: 1642.0000 - false_negatives_1: 3491.0000
#
#  LSTM 테스트 결과: [1.0711084604263306, 0.5169850587844849, 0.5164251923561096, 0.7151786684989929, 0.5317865014076233, 0.7071517705917358, 3965.0, 1529.0, 1642.0, 3491.0]

# %%
# GRU모델 성능 평가 
loaded_model = load_model('RNN_GRU_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5')
result = loaded_model.evaluate(X_test_total2, y_test_total2, batch_size=100)
print("\n GRU 테스트 결과:",result)
# Out:
# 107/107 [==============================] - 2s 7ms/step - loss: 1.0238 - acc: 0.5225 - auc_2: 0.5140 - auc_3: 0.7170 - recall_1: 0.5465 - precision_1: 0.7065 - true_positives_1: 4075.0000 - true_negatives_1: 1478.0000 - false_positives_1: 1693.0000 - false_negatives_1: 3381.0000
#
#  GRU 테스트 결과: [1.0237617492675781, 0.5225369334220886, 0.5139856934547424, 0.7169529795646667, 0.5465397238731384, 0.7064840793609619, 4075.0, 1478.0, 1693.0, 3381.0]

# %%
# BiLSTM모델 성능 평가 
loaded_model = load_model('RNN_BiLSTM_KoNLPy(Okt)_Total(movie+shopping+game)_v0.2.h5')
result = loaded_model.evaluate(X_test_total2, y_test_total2, batch_size=100)
print("\n BiLSTM 테스트 결과:",result)
# Out:
# 107/107 [==============================] - 2s 8ms/step - loss: 1.1577 - acc: 0.4876 - auc_2: 0.5161 - auc_3: 0.7182 - recall_1: 0.4580 - precision_1: 0.7087 - true_positives_1: 3415.0000 - true_negatives_1: 1767.0000 - false_positives_1: 1404.0000 - false_negatives_1: 4041.0000
#
#  BiLSTM 테스트 결과: [1.1576929092407227, 0.4876258671283722, 0.5160806179046631, 0.7181856632232666, 0.4580203890800476, 0.7086532711982727, 3415.0, 1767.0, 1404.0, 4041.0]
